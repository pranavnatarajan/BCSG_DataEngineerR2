# %% [markdown]
# # BCSG Data Engineer - Data Engineering Project

# %% [markdown]
# Importing the requried packages

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import sqlite3

# %% [markdown]
# I decided on using transfermarkt to obtain the team and player valuation data. Though most of the valuation is based on the Transfermarkt Community, they have some quantitative pointers for the same.

# %% [markdown]
# First, I will get the data of the clubs for the 22/23 season

# %%
# setting the user agent to prevent blocks for scraping
header = {'User-Agent': 
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
# for the clubs values for the 22/23 season
clubs_url = r"https://www.transfermarkt.us/laliga/startseite/wettbewerb/ES1"

# %%
# instantiating the requests object for the web scraping
req = requests.get(url=clubs_url, headers=header)
# instantiatingt he beautifulSoup Object
bs_obj = BeautifulSoup(req.content, "html.parser")

# %%
# finding the table
clubs_table = bs_obj.find('table', attrs={'class':'items'})
# drilling down to body of the table
table_body = clubs_table.find('tbody')

# instantiating the list of lists for the dataframe
clubs_df = []
# finding all the rows in the table
rows = table_body.find_all('tr')
for row in rows:
    # getting the data from each column for each row
    cols = row.find_all('td')
    # removing whitespaces around the column value text
    cols = [val.text.strip() for val in cols]
    # append list of all the value text to clubs_df i.e, each row-tuple
    clubs_df.append([val for val in cols if val]) # Get rid of empty values if they exist

# %%
clubs_df
# Out:
# [['Real Madrid', '23', '27.4', '16', '$40.05m', '$921.25m'],
#  ['FC Barcelona', '25', '25.4', '10', '$35.80m', '$895.07m'],
#  ['Atlético de Madrid', '22', '27.8', '16', '$30.58m', '$672.65m'],
#  ['Real Sociedad', '27', '24.8', '5', '$15.13m', '$408.43m'],
#  ['Villarreal CF', '25', '28.0', '11', '$15.85m', '$396.22m'],
#  ['Sevilla FC', '25', '28.5', '18', '$12.17m', '$304.15m'],
#  ['Real Betis Balompié', '26', '28.8', '12', '$11.00m', '$286.00m'],
#  ['Valencia CF', '25', '24.4', '14', '$10.44m', '$260.92m'],
#  ['Athletic Bilbao', '25', '27.3', '1', '$10.42m', '$260.59m'],
#  ['Getafe CF', '24', '27.3', '12', '$6.61m', '$158.73m'],
#  ['Celta de Vigo', '22', '26.0', '9', '$6.44m', '$141.57m'],
#  ['CA Osasuna', '24', '27.6', '5', '$5.68m', '$136.40m'],
#  ['RCD Espanyol Barcelona', '21', '26.5', '5', '$4.83m', '$101.42m'],
#  ['Girona FC', '26', '26.0', '9', '$3.88m', '$100.76m'],
#  ['UD Almería', '28', '25.4', '13', '$3.42m', '$95.70m'],
#  ['Rayo Vallecano', '27', '28.1', '10', '$3.36m', '$90.75m'],
#  ['Elche CF', '25', '28.0', '9', '$3.18m', '$79.42m'],
#  ['RCD Mallorca', '25', '27.8', '15', '$3.15m', '$78.76m'],
#  ['Real Valladolid CF', '25', '27.7', '10', '$2.87m', '$71.67m'],
#  ['Cádiz CF', '27', '28.6', '9', '$2.65m', '$71.50m']]

# %% [markdown]
# I use pandas dataframes for easier data manipulation (i.e using an `apply()` function and intuitive removal of columns) & making bulk insertions easier through the `itertuples()` function, as you will see in subsequent steps.

# %%
# creating pandas dataframe of clubs_df
clubs_df1 = pd.DataFrame(clubs_df)

# %%
# creating the column names
clubs_df1.columns = ["Name", "Squad", "Avg Squad Age",
"Foreigners", "Avg Market Value ($)",
"Total Market Value ($)"]

# %%
clubs_df1.head()
# Out:
#                  Name Squad Avg Squad Age Foreigners Avg Market Value ($)  \
# 0         Real Madrid    23          27.4         16              $40.05m
# 1        FC Barcelona    25          25.4         10              $35.80m
# 2  Atlético de Madrid    22          27.8         16              $30.58m
# 3       Real Sociedad    27          24.8          5              $15.13m
# 4       Villarreal CF    25          28.0         11              $15.85m
#
#   Total Market Value ($)
# 0               $921.25m
# 1               $895.07m
# 2               $672.65m
# 3               $408.43m
# 4               $396.22m

# %% [markdown]
# Now, we need to format the market values, to make them be numbers.
# We need to remove the `$` sign, and multiply by (10^6) if "m" , or (10^3) if "Th." exists in the string

# %%
# function that takes in a string of market value as input, and makes it a number
def str_to_float(str):
  """function to convert market values from string to floating point

  Args:
      str (string): string literal of market value

  Returns:
      float: the floating point representation of the string literal
  """
  # removing all whitespaces around the string
  str = str.strip()
  # get the suffix
  suffix = str[-1]
  # get the number, by removing the $ and suffix
  num = str.replace("$", "")
  # multiplication by respective power of 10
  # based on suffix
  # for a million
  if suffix == "m":
    num = float(num[:len(num)-1])
    num = num * (10 ** 6)
  # for a thousand
  else:
    num = float(num[:len(num)-3])
    num = num * (10 ** 3)
  # returning the floating point number
  return num

# %%
# using the apply function on the dataset
clubs_df1["Avg Market Value ($)"] = clubs_df1["Avg Market Value ($)"].apply(str_to_float)
clubs_df1["Total Market Value ($)"] = clubs_df1["Total Market Value ($)"].apply(str_to_float)

# %%
# checking whether the other datatypes need changing
clubs_df1.dtypes
# Out:
# Name                       object
# Squad                      object
# Avg Squad Age              object
# Foreigners                 object
# Avg Market Value ($)      float64
# Total Market Value ($)    float64
# dtype: object

# %% [markdown]
# We need to change the `Squad`, `Avg Squad Age`, and `Foreigners` columns to be numeric.

# %%
# checking the datatypes of the respective columns
clubs_df1.loc[:, ["Squad", "Avg Squad Age", "Foreigners"]] = clubs_df1.loc[:,
["Squad", "Avg Squad Age", "Foreigners"]].apply(pd.to_numeric)

# %%
# final check before saving onto sqlite main schema
clubs_df1.head()
# Out:
#                  Name  Squad  Avg Squad Age  Foreigners  Avg Market Value ($)  \
# 0         Real Madrid     23           27.4          16            40050000.0
# 1        FC Barcelona     25           25.4          10            35800000.0
# 2  Atlético de Madrid     22           27.8          16            30580000.0
# 3       Real Sociedad     27           24.8           5            15130000.0
# 4       Villarreal CF     25           28.0          11            15850000.0
#
#    Total Market Value ($)
# 0             921250000.0
# 1             895070000.0
# 2             672650000.0
# 3             408430000.0
# 4             396220000.0

# %%
clubs_df1.dtypes
# Out:
# Name                       object
# Squad                       int64
# Avg Squad Age             float64
# Foreigners                  int64
# Avg Market Value ($)      float64
# Total Market Value ($)    float64
# dtype: object

# %% [markdown]
# Now, we will obtain the data for the players in the clubs. I will create a list of urls for the player data by club from the *`compact`* tables on the Transfermarkt website, which will get appended in one master table for the players.

# %%
player_tables_urls_compact = [r"https://www.transfermarkt.us/real-madrid/kader/verein/418/saison_id/2022",
r"https://www.transfermarkt.us/fc-barcelona/kader/verein/131/saison_id/2022",
r"https://www.transfermarkt.us/atletico-de-madrid/kader/verein/13/saison_id/2022",
r"https://www.transfermarkt.us/real-sociedad/kader/verein/681/saison_id/2022",
r"https://www.transfermarkt.us/villarreal-cf/kader/verein/1050/saison_id/2022",
r"https://www.transfermarkt.us/sevilla-fc/kader/verein/368/saison_id/2022",
r"https://www.transfermarkt.us/real-betis-balompie/kader/verein/150/saison_id/2022",
r"https://www.transfermarkt.us/valencia-cf/kader/verein/1049/saison_id/2022",
r"https://www.transfermarkt.us/athletic-bilbao/kader/verein/621/saison_id/2022",
r"https://www.transfermarkt.us/getafe-cf/kader/verein/3709/saison_id/2022",
r"https://www.transfermarkt.us/celta-de-vigo/kader/verein/940/saison_id/2022",
r"https://www.transfermarkt.us/ca-osasuna/kader/verein/331/saison_id/2022",
r"https://www.transfermarkt.us/rcd-espanyol-barcelona/kader/verein/714/saison_id/2022",
r"https://www.transfermarkt.us/girona-fc/kader/verein/12321/saison_id/2022",
r"https://www.transfermarkt.us/ud-almeria/kader/verein/3302/saison_id/2022",
r"https://www.transfermarkt.us/rayo-vallecano/kader/verein/367/saison_id/2022",
r"https://www.transfermarkt.us/elche-cf/kader/verein/1531/saison_id/2022",
r"https://www.transfermarkt.us/rcd-mallorca/kader/verein/237/saison_id/2022",
r"https://www.transfermarkt.us/real-valladolid-cf/kader/verein/366/saison_id/2022",
r"https://www.transfermarkt.us/cadiz-cf/kader/verein/2687/saison_id/2022"]

# %%
# creating the list of lists object for the players
players = []

# over all the teams' detailed table webpages
for i in range(len(player_tables_urls_compact)):
    # instantiate new request object
    req_1 = requests.get(player_tables_urls_compact[i], headers=header)
    # instantiating the new beautifulSoup Object for the team webpage
    bs_players_obj = BeautifulSoup(req_1.content, "html.parser")
    # finding the table
    player_table = bs_players_obj.find('table', attrs={'class':'items'})
    # drilling down to body of the table
    table_body = player_table.find('tbody')

    # finding all the rows in the table
    rows = table_body.find_all('tr')
    for row in rows:
        # getting the data from each column for each row
        cols = row.find_all('td')
        # removing whitespaces around the column value text
        cols = [val.text.strip() for val in cols]
        # adding the team name
        # since it is the foreign key reference to the clubs table
        cols.append(clubs_df1["Name"][i])
        # Get rid of empty values if they exist
        # NOTE: the nationality & duplicate kit number columns turn up empty
        # due to there being more recursion required to obtain the text fields.
        # Since it isn't relevant to this project it will be removed.
        # We do not need kit number either, so it will be removed as well.
        players.append([val for val in cols])

# %%
# getting the first two records for the players table
players[0:6]
# Out:
# [['1',
#   'Thibaut Courtois            \n\n\n\n\n            Goalkeeper',
#   '',
#   'Thibaut Courtois',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$66.00m',
#   'Real Madrid'],
#  ['', 'Thibaut Courtois', 'Real Madrid'],
#  ['Goalkeeper', 'Real Madrid'],
#  ['13',
#   'Andriy Lunin            \n\n\n\n\n            Goalkeeper',
#   '',
#   'Andriy Lunin',
#   'Goalkeeper',
#   '23',
#   '',
#   'Jun 30, 2024',
#   '$2.75m',
#   'Real Madrid'],
#  ['', 'Andriy Lunin', 'Real Madrid'],
#  ['Goalkeeper', 'Real Madrid']]

# %% [markdown]
# Note that we need to remove the first 2 entries in each list, which means we need to delete the lists that have lesser than 3 elements *completely* from our list of lists.

# %%
# removing the lists of length less than 3
players = [row for row in players if len(row) > 3]
# removing the first 2 elements of the remaining lists
players = [row[2:] for row in players]

# %%
players
# Out:
# [['',
#   'Thibaut Courtois',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$66.00m',
#   'Real Madrid'],
#  ['',
#   'Andriy Lunin',
#   'Goalkeeper',
#   '23',
#   '',
#   'Jun 30, 2024',
#   '$2.75m',
#   'Real Madrid'],
#  ['',
#   'Éder Militão',
#   'Centre-Back',
#   '24',
#   '',
#   'Jun 30, 2025',
#   '$66.00m',
#   'Real Madrid'],
#  ['',
#   'David Alaba',
#   'Centre-Back',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$60.50m',
#   'Real Madrid'],
#  ['',
#   'Antonio Rüdiger',
#   'Centre-Back',
#   '29',
#   '',
#   'Jun 30, 2026',
#   '$44.00m',
#   'Real Madrid'],
#  ['',
#   'Nacho Fernández',
#   'Centre-Back',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$7.70m',
#   'Real Madrid'],
#  ['',
#   'Jesús Vallejo',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Real Madrid'],
#  ['',
#   'Ferland Mendy',
#   'Left-Back',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$44.00m',
#   'Real Madrid'],
#  ['',
#   'Daniel Carvajal',
#   'Right-Back',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$19.80m',
#   'Real Madrid'],
#  ['',
#   'Álvaro Odriozola',
#   'Right-Back',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$11.00m',
#   'Real Madrid'],
#  ['',
#   'Aurélien Tchouameni',
#   'Defensive Midfield',
#   '22',
#   '',
#   'Jun 30, 2028',
#   '$88.00m',
#   'Real Madrid'],
#  ['',
#   'Federico Valverde',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2027',
#   '$88.00m',
#   'Real Madrid'],
#  ['',
#   'Eduardo Camavinga',
#   'Central Midfield',
#   '19',
#   '',
#   'Jun 30, 2027',
#   '$60.50m',
#   'Real Madrid'],
#  ['',
#   'Toni Kroos',
#   'Central Midfield',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$22.00m',
#   'Real Madrid'],
#  ['',
#   'Dani Ceballos',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$15.40m',
#   'Real Madrid'],
#  ['',
#   'Luka Modric',
#   'Central Midfield',
#   '37',
#   '',
#   'Jun 30, 2023',
#   '$11.00m',
#   'Real Madrid'],
#  ['',
#   'Vinicius Junior',
#   'Left Winger',
#   '22',
#   '',
#   'Jun 30, 2024',
#   '$132.00m',
#   'Real Madrid'],
#  ['',
#   'Eden Hazard',
#   'Left Winger',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$13.20m',
#   'Real Madrid'],
#  ['',
#   'Rodrygo',
#   'Right Winger',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$77.00m',
#   'Real Madrid'],
#  ['',
#   'Marco Asensio',
#   'Right Winger',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$38.50m',
#   'Real Madrid'],
#  ['',
#   'Lucas Vázquez',
#   'Right Winger',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$13.20m',
#   'Real Madrid'],
#  ['',
#   'Karim Benzema',
#   'Centre-Forward',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$33.00m',
#   'Real Madrid'],
#  ['',
#   'Mariano Díaz',
#   'Centre-Forward',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Real Madrid'],
#  ['',
#   'Marc-André ter Stegen',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$33.00m',
#   'FC Barcelona'],
#  ['',
#   'Iñaki Peña',
#   'Goalkeeper',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$4.62m',
#   'FC Barcelona'],
#  ['',
#   'Arnau Tenas',
#   'Goalkeeper',
#   '21',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'FC Barcelona'],
#  ['',
#   'Ronald Araújo',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$66.00m',
#   'FC Barcelona'],
#  ['',
#   'Jules Koundé',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2027',
#   '$66.00m',
#   'FC Barcelona'],
#  ['',
#   'Andreas Christensen',
#   'Centre-Back',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$38.50m',
#   'FC Barcelona'],
#  ['',
#   'Eric García',
#   'Centre-Back',
#   '21',
#   '',
#   'Jun 30, 2026',
#   '$19.80m',
#   'FC Barcelona'],
#  ['',
#   'Gerard Piqué',
#   'Centre-Back',
#   '35',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'FC Barcelona'],
#  ['',
#   'Marcos Alonso',
#   'Left-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$13.20m',
#   'FC Barcelona'],
#  ['',
#   'Jordi Alba',
#   'Left-Back',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$9.90m',
#   'FC Barcelona'],
#  ['',
#   'Alejandro Balde',
#   'Left-Back',
#   '19',
#   '',
#   'Jun 30, 2024',
#   '$8.80m',
#   'FC Barcelona'],
#  ['',
#   'Héctor Bellerín',
#   'Right-Back',
#   '27',
#   '',
#   'Jun 30, 2023',
#   '$22.00m',
#   'FC Barcelona'],
#  ['',
#   'Sergi Roberto',
#   'Right-Back',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'FC Barcelona'],
#  ['',
#   'Sergio Busquets',
#   'Defensive Midfield',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$9.90m',
#   'FC Barcelona'],
#  ['',
#   'Pedri',
#   'Central Midfield',
#   '19',
#   '',
#   'Jun 30, 2026',
#   '$99.00m',
#   'FC Barcelona'],
#  ['',
#   'Gavi',
#   'Central Midfield',
#   '18',
#   '',
#   'Jun 30, 2026',
#   '$77.00m',
#   'FC Barcelona'],
#  ['',
#   'Frenkie de Jong',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$66.00m',
#   'FC Barcelona'],
#  ['',
#   'Franck Kessié',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$49.50m',
#   'FC Barcelona'],
#  ['',
#   'Pablo Torre',
#   'Attacking Midfield',
#   '19',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'FC Barcelona'],
#  ['',
#   'Ansu Fati',
#   'Left Winger',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$66.00m',
#   'FC Barcelona'],
#  ['',
#   'Ferran Torres',
#   'Left Winger',
#   '22',
#   '',
#   'Jun 30, 2027',
#   '$44.00m',
#   'FC Barcelona'],
#  ['',
#   'Ousmane Dembélé',
#   'Right Winger',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$55.00m',
#   'FC Barcelona'],
#  ['',
#   'Raphinha',
#   'Right Winger',
#   '25',
#   '',
#   'Jun 30, 2027',
#   '$55.00m',
#   'FC Barcelona'],
#  ['',
#   'Robert Lewandowski',
#   'Centre-Forward',
#   '34',
#   '',
#   'Jun 30, 2026',
#   '$49.50m',
#   'FC Barcelona'],
#  ['',
#   'Memphis Depay',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2023',
#   '$27.50m',
#   'FC Barcelona'],
#  ['',
#   'Jan Oblak',
#   'Goalkeeper',
#   '29',
#   '',
#   'Jun 30, 2028',
#   '$44.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Ivo Grbic',
#   'Goalkeeper',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$3.85m',
#   'Atlético de Madrid'],
#  ['',
#   'José María Giménez',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$49.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Mario Hermoso',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$19.80m',
#   'Atlético de Madrid'],
#  ['',
#   'Stefan Savic',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$15.40m',
#   'Atlético de Madrid'],
#  ['',
#   'Felipe',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'Atlético de Madrid'],
#  ['',
#   'Sergio Reguilón',
#   'Left-Back',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$27.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Reinildo Mandava',
#   'Left-Back',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$27.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Nahuel Molina',
#   'Right-Back',
#   '24',
#   '',
#   'Jun 30, 2027',
#   '$22.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Geoffrey Kondogbia',
#   'Defensive Midfield',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$22.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Axel Witsel',
#   'Defensive Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Marcos Llorente',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2027',
#   '$44.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Rodrigo de Paul',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$38.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Koke',
#   'Central Midfield',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$22.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Saúl Ñíguez',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$22.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Thomas Lemar',
#   'Attacking Midfield',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$38.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Yannick Carrasco',
#   'Left Winger',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$44.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Ángel Correa',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$44.00m',
#   'Atlético de Madrid'],
#  ['',
#   'João Félix',
#   'Second Striker',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$77.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Antoine Griezmann',
#   'Second Striker',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$38.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Matheus Cunha',
#   'Centre-Forward',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$33.00m',
#   'Atlético de Madrid'],
#  ['',
#   'Álvaro Morata',
#   'Centre-Forward',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$27.50m',
#   'Atlético de Madrid'],
#  ['',
#   'Álex Remiro',
#   'Goalkeeper',
#   '27',
#   '',
#   'Jun 30, 2027',
#   '$24.20m',
#   'Real Sociedad'],
#  ['',
#   'Andoni Zubiaurre',
#   'Goalkeeper',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$330Th.',
#   'Real Sociedad'],
#  ['',
#   'Robin Le Normand',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$38.50m',
#   'Real Sociedad'],
#  ['',
#   'Aritz Elustondo',
#   'Centre-Back',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$22.00m',
#   'Real Sociedad'],
#  ['',
#   'Igor Zubeldia',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$16.50m',
#   'Real Sociedad'],
#  ['',
#   'Jon Pacheco',
#   'Centre-Back',
#   '21',
#   '',
#   'Jun 30, 2027',
#   '$1.10m',
#   'Real Sociedad'],
#  ['',
#   'Aihen Muñoz',
#   'Left-Back',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$6.60m',
#   'Real Sociedad'],
#  ['',
#   'Diego Rico',
#   'Left-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Real Sociedad'],
#  ['',
#   'Andoni Gorosabel',
#   'Right-Back',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$11.00m',
#   'Real Sociedad'],
#  ['',
#   'Álex Sola',
#   'Right-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'Real Sociedad'],
#  ['',
#   'Martín Zubimendi',
#   'Defensive Midfield',
#   '23',
#   '',
#   'Jun 30, 2027',
#   '$38.50m',
#   'Real Sociedad'],
#  ['',
#   'Asier Illarramendi',
#   'Defensive Midfield',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Real Sociedad'],
#  ['',
#   'Mikel Merino',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2025',
#   '$55.00m',
#   'Real Sociedad'],
#  ['',
#   'Ander Guevara',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Real Sociedad'],
#  ['',
#   'Beñat Turrientes',
#   'Central Midfield',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$3.30m',
#   'Real Sociedad'],
#  ['',
#   'Brais Méndez',
#   'Right Midfield',
#   '25',
#   '',
#   'Jun 30, 2028',
#   '$24.20m',
#   'Real Sociedad'],
#  ['',
#   'David Silva',
#   'Attacking Midfield',
#   '36',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Real Sociedad'],
#  ['',
#   'Robert Navarro',
#   'Attacking Midfield',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$3.30m',
#   'Real Sociedad'],
#  ['',
#   'Mikel Oyarzabal',
#   'Left Winger',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$66.00m',
#   'Real Sociedad'],
#  ['',
#   'Ander Barrenetxea',
#   'Left Winger',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$9.90m',
#   'Real Sociedad'],
#  ['',
#   'Martín Merquelanz',
#   'Left Winger',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$1.65m',
#   'Real Sociedad'],
#  ['',
#   'Takefusa Kubo',
#   'Right Winger',
#   '21',
#   '',
#   'Jun 30, 2027',
#   '$9.90m',
#   'Real Sociedad'],
#  ['',
#   'Umar Sadiq',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2028',
#   '$19.80m',
#   'Real Sociedad'],
#  ['',
#   'Momo Cho',
#   'Centre-Forward',
#   '18',
#   '',
#   'Jun 30, 2027',
#   '$16.50m',
#   'Real Sociedad'],
#  ['',
#   'Alexander Sörloth',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$11.00m',
#   'Real Sociedad'],
#  ['',
#   'Carlos Fernández',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Real Sociedad'],
#  ['',
#   'Jon Karrikaburu',
#   'Centre-Forward',
#   '20',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Real Sociedad'],
#  ['',
#   'Gerónimo Rulli',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$6.60m',
#   'Villarreal CF'],
#  ['',
#   'Filip Jörgensen',
#   'Goalkeeper',
#   '20',
#   '',
#   'Jun 30, 2025',
#   '$1.10m',
#   'Villarreal CF'],
#  ['',
#   'Pepe Reina',
#   'Goalkeeper',
#   '40',
#   '',
#   'Jun 30, 2023',
#   '$770Th.',
#   'Villarreal CF'],
#  ['',
#   'Pau Torres',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$55.00m',
#   'Villarreal CF'],
#  ['',
#   'Jorge Cuenca',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2025',
#   '$8.80m',
#   'Villarreal CF'],
#  ['',
#   'Aïssa Mandi',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'Villarreal CF'],
#  ['',
#   'Raúl Albiol',
#   'Centre-Back',
#   '37',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Villarreal CF'],
#  ['',
#   'Alfonso Pedraza',
#   'Left-Back',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$19.80m',
#   'Villarreal CF'],
#  ['',
#   'Johan Mojica',
#   'Left-Back',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Villarreal CF'],
#  ['',
#   'Alberto Moreno',
#   'Left-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Villarreal CF'],
#  ['',
#   'Juan Foyth',
#   'Right-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$27.50m',
#   'Villarreal CF'],
#  ['',
#   'Kiko Femenía',
#   'Right-Back',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'Villarreal CF'],
#  ['',
#   'Francis Coquelin',
#   'Defensive Midfield',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Villarreal CF'],
#  ['',
#   'Étienne Capoue',
#   'Defensive Midfield',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Villarreal CF'],
#  ['',
#   'Giovani Lo Celso',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$24.20m',
#   'Villarreal CF'],
#  ['',
#   'Manu Trigueros',
#   'Central Midfield',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$13.20m',
#   'Villarreal CF'],
#  ['',
#   'Dani Parejo',
#   'Central Midfield',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$9.90m',
#   'Villarreal CF'],
#  ['',
#   'Manu Morlanes',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Villarreal CF'],
#  ['',
#   'Álex Baena',
#   'Left Winger',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$11.00m',
#   'Villarreal CF'],
#  ['',
#   'Yéremy Pino',
#   'Right Winger',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$44.00m',
#   'Villarreal CF'],
#  ['',
#   'Samuel Chukwueze',
#   'Right Winger',
#   '23',
#   '',
#   'Jun 30, 2024',
#   '$22.00m',
#   'Villarreal CF'],
#  ['',
#   'Nicolas Jackson',
#   'Right Winger',
#   '21',
#   '',
#   'Jun 30, 2023',
#   '$11.00m',
#   'Villarreal CF'],
#  ['',
#   'Arnaut Danjuma',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$55.00m',
#   'Villarreal CF'],
#  ['',
#   'Gerard Moreno',
#   'Centre-Forward',
#   '30',
#   '',
#   'Jun 30, 2027',
#   '$44.00m',
#   'Villarreal CF'],
#  ['',
#   'José Luis Morales',
#   'Centre-Forward',
#   '35',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Villarreal CF'],
#  ['', 'Bono', 'Goalkeeper', '31', '', 'Jun 30, 2025', '$19.80m', 'Sevilla FC'],
#  ['',
#   'Marko Dmitrović',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Sevilla FC'],
#  ['',
#   'Marcão',
#   'Centre-Back',
#   '26',
#   '',
#   'Jun 30, 2027',
#   '$15.40m',
#   'Sevilla FC'],
#  ['',
#   'Tanguy Nianzou',
#   'Centre-Back',
#   '20',
#   '',
#   'Jun 30, 2027',
#   '$9.90m',
#   'Sevilla FC'],
#  ['',
#   'Karim Rekik',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Sevilla FC'],
#  ['',
#   'Alex Telles',
#   'Left-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$19.80m',
#   'Sevilla FC'],
#  ['',
#   'Marcos Acuña',
#   'Left-Back',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$19.80m',
#   'Sevilla FC'],
#  ['',
#   'Gonzalo Montiel',
#   'Right-Back',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$15.40m',
#   'Sevilla FC'],
#  ['',
#   'José Ángel Carmona',
#   'Right-Back',
#   '20',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Sevilla FC'],
#  ['',
#   'Jesús Navas',
#   'Right-Back',
#   '36',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Sevilla FC'],
#  ['',
#   'Nemanja Gudelj',
#   'Defensive Midfield',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Sevilla FC'],
#  ['',
#   'Fernando',
#   'Defensive Midfield',
#   '35',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Sevilla FC'],
#  ['',
#   'Joan Jordán',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$19.80m',
#   'Sevilla FC'],
#  ['',
#   'Óliver Torres',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$8.80m',
#   'Sevilla FC'],
#  ['',
#   'Ivan Rakitic',
#   'Central Midfield',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$7.70m',
#   'Sevilla FC'],
#  ['',
#   'Thomas Delaney',
#   'Central Midfield',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$7.70m',
#   'Sevilla FC'],
#  ['',
#   'Isco',
#   'Attacking Midfield',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$8.25m',
#   'Sevilla FC'],
#  ['',
#   'Papu Gómez',
#   'Left Winger',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$6.60m',
#   'Sevilla FC'],
#  ['',
#   'Tecatito',
#   'Right Winger',
#   '29',
#   '',
#   'Jun 30, 2025',
#   '$19.80m',
#   'Sevilla FC'],
#  ['',
#   'Erik Lamela',
#   'Right Winger',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$17.60m',
#   'Sevilla FC'],
#  ['',
#   'Suso',
#   'Right Winger',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$11.00m',
#   'Sevilla FC'],
#  ['',
#   'Adnan Januzaj',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$9.90m',
#   'Sevilla FC'],
#  ['',
#   'Youssef En-Nesyri',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$22.00m',
#   'Sevilla FC'],
#  ['',
#   'Kasper Dolberg',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$18.70m',
#   'Sevilla FC'],
#  ['',
#   'Rafa Mir',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2027',
#   '$17.60m',
#   'Sevilla FC'],
#  ['',
#   'Rui Silva',
#   'Goalkeeper',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$16.50m',
#   'Real Betis Balompié'],
#  ['',
#   'Dani Martín',
#   'Goalkeeper',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Real Betis Balompié'],
#  ['',
#   'Claudio Bravo',
#   'Goalkeeper',
#   '39',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Real Betis Balompié'],
#  ['',
#   'Luiz Felipe',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2027',
#   '$19.80m',
#   'Real Betis Balompié'],
#  ['',
#   'Edgar González',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$8.80m',
#   'Real Betis Balompié'],
#  ['',
#   'Germán Pezzella',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Real Betis Balompié'],
#  ['',
#   'Víctor Ruiz',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Real Betis Balompié'],
#  ['',
#   'Álex Moreno',
#   'Left-Back',
#   '29',
#   '',
#   'Jun 30, 2025',
#   '$19.80m',
#   'Real Betis Balompié'],
#  ['',
#   'Juan Miranda',
#   'Left-Back',
#   '22',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Real Betis Balompié'],
#  ['',
#   'Youssouf Sabaly',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Real Betis Balompié'],
#  ['',
#   'Aitor Ruibal',
#   'Right-Back',
#   '26',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Real Betis Balompié'],
#  ['',
#   'Martín Montoya',
#   'Right-Back',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$1.65m',
#   'Real Betis Balompié'],
#  ['',
#   'Guido Rodríguez',
#   'Defensive Midfield',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$27.50m',
#   'Real Betis Balompié'],
#  ['',
#   'William Carvalho',
#   'Defensive Midfield',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$17.60m',
#   'Real Betis Balompié'],
#  ['',
#   'Paul Akouokou',
#   'Defensive Midfield',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Real Betis Balompié'],
#  ['',
#   'Andrés Guardado',
#   'Central Midfield',
#   '36',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Real Betis Balompié'],
#  ['',
#   'Víctor Camarasa',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Real Betis Balompié'],
#  ['',
#   'Nabil Fekir',
#   'Attacking Midfield',
#   '29',
#   '',
#   'Jun 30, 2026',
#   '$44.00m',
#   'Real Betis Balompié'],
#  ['',
#   'Sergio Canales',
#   'Attacking Midfield',
#   '31',
#   '',
#   'Jun 30, 2026',
#   '$22.00m',
#   'Real Betis Balompié'],
#  ['',
#   'Rodri Sánchez',
#   'Attacking Midfield',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$7.70m',
#   'Real Betis Balompié'],
#  ['',
#   'Juanmi',
#   'Left Winger',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$16.50m',
#   'Real Betis Balompié'],
#  ['',
#   'Luiz Henrique',
#   'Right Winger',
#   '21',
#   '',
#   'Jun 30, 2028',
#   '$13.20m',
#   'Real Betis Balompié'],
#  ['',
#   'Joaquín',
#   'Right Winger',
#   '41',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Real Betis Balompié'],
#  ['',
#   'Borja Iglesias',
#   'Centre-Forward',
#   '29',
#   '',
#   'Jun 30, 2026',
#   '$22.00m',
#   'Real Betis Balompié'],
#  ['',
#   'Willian José',
#   'Centre-Forward',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$13.20m',
#   'Real Betis Balompié'],
#  ['',
#   'Loren Morón',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Real Betis Balompié'],
#  ['',
#   'Giorgi Mamardashvili',
#   'Goalkeeper',
#   '22',
#   '',
#   'Jun 30, 2027',
#   '$22.00m',
#   'Valencia CF'],
#  ['',
#   'Jaume Doménech',
#   'Goalkeeper',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Valencia CF'],
#  ['',
#   'Iago Herrerín',
#   'Goalkeeper',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$550Th.',
#   'Valencia CF'],
#  ['',
#   'Cristian Rivero',
#   'Goalkeeper',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$220Th.',
#   'Valencia CF'],
#  ['',
#   'Mouctar Diakhaby',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$8.80m',
#   'Valencia CF'],
#  ['',
#   'Gabriel Paulista',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Valencia CF'],
#  ['',
#   'Cenk Özkacar',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Valencia CF'],
#  ['',
#   'Eray Cömert',
#   'Centre-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$2.20m',
#   'Valencia CF'],
#  ['',
#   'Cristhian Mosquera',
#   'Centre-Back',
#   '18',
#   '',
#   'Jun 30, 2025',
#   '$1.10m',
#   'Valencia CF'],
#  ['',
#   'José Gayà',
#   'Left-Back',
#   '27',
#   '',
#   'Jun 30, 2027',
#   '$38.50m',
#   'Valencia CF'],
#  ['',
#   'Jesús Vázquez',
#   'Left-Back',
#   '19',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Valencia CF'],
#  ['',
#   'Toni Lato',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Valencia CF'],
#  ['',
#   'Thierry Correia',
#   'Right-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$13.20m',
#   'Valencia CF'],
#  ['',
#   'Dimitri Foulquier',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Valencia CF'],
#  ['',
#   'Hugo Guillamón',
#   'Defensive Midfield',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$27.50m',
#   'Valencia CF'],
#  ['',
#   'Yunus Musah',
#   'Central Midfield',
#   '19',
#   '',
#   'Jun 30, 2026',
#   '$27.50m',
#   'Valencia CF'],
#  ['',
#   'Nico González',
#   'Central Midfield',
#   '20',
#   '',
#   'Jun 30, 2023',
#   '$22.00m',
#   'Valencia CF'],
#  ['',
#   'Ilaix Moriba',
#   'Central Midfield',
#   '19',
#   '',
#   'Jun 30, 2023',
#   '$9.90m',
#   'Valencia CF'],
#  ['',
#   'André Almeida',
#   'Central Midfield',
#   '22',
#   '',
#   'Jun 30, 2028',
#   '$8.80m',
#   'Valencia CF'],
#  ['',
#   'Justin Kluivert',
#   'Left Winger',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$16.50m',
#   'Valencia CF'],
#  ['',
#   'Samuel Lino',
#   'Left Winger',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$13.20m',
#   'Valencia CF'],
#  ['',
#   'Samu Castillejo',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'Valencia CF'],
#  ['',
#   'Hugo Duro',
#   'Centre-Forward',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$11.00m',
#   'Valencia CF'],
#  ['',
#   'Marcos André',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Valencia CF'],
#  ['',
#   'Edinson Cavani',
#   'Centre-Forward',
#   '35',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Valencia CF'],
#  ['',
#   'Unai Simón',
#   'Goalkeeper',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$27.50m',
#   'Athletic Bilbao'],
#  ['',
#   'Julen Agirrezabala',
#   'Goalkeeper',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Athletic Bilbao'],
#  ['',
#   'Iñigo Martínez',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$22.00m',
#   'Athletic Bilbao'],
#  ['',
#   'Dani Vivian',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$16.50m',
#   'Athletic Bilbao'],
#  ['',
#   'Yeray Álvarez',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$14.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Aitor Paredes',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2025',
#   '$440Th.',
#   'Athletic Bilbao'],
#  ['',
#   'Yuri Berchiche',
#   'Left-Back',
#   '32',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Mikel Balenziaga',
#   'Left-Back',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$1.32m',
#   'Athletic Bilbao'],
#  ['',
#   'Iñigo Lekue',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Ander Capa',
#   'Right-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$2.75m',
#   'Athletic Bilbao'],
#  ['',
#   'Óscar de Marcos',
#   'Right-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.98m',
#   'Athletic Bilbao'],
#  ['',
#   'Mikel Vesga',
#   'Defensive Midfield',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Unai Vencedor',
#   'Central Midfield',
#   '21',
#   '',
#   'Jun 30, 2027',
#   '$22.00m',
#   'Athletic Bilbao'],
#  ['',
#   'Ander Herrera',
#   'Central Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$8.80m',
#   'Athletic Bilbao'],
#  ['',
#   'Oier Zarraga',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$3.85m',
#   'Athletic Bilbao'],
#  ['',
#   'Dani García',
#   'Central Midfield',
#   '32',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Oihan Sancet',
#   'Attacking Midfield',
#   '22',
#   '',
#   'Jun 30, 2024',
#   '$22.00m',
#   'Athletic Bilbao'],
#  ['',
#   'Iker Muniain',
#   'Attacking Midfield',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$17.60m',
#   'Athletic Bilbao'],
#  ['',
#   'Jon Morcillo',
#   'Left Winger',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Athletic Bilbao'],
#  ['',
#   'Nico Williams',
#   'Right Winger',
#   '20',
#   '',
#   'Jun 30, 2024',
#   '$24.20m',
#   'Athletic Bilbao'],
#  ['',
#   'Álex Berenguer',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$16.50m',
#   'Athletic Bilbao'],
#  ['',
#   'Iñaki Williams',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2028',
#   '$27.50m',
#   'Athletic Bilbao'],
#  ['',
#   'Asier Villalibre',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Athletic Bilbao'],
#  ['',
#   'Raúl García',
#   'Centre-Forward',
#   '36',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Athletic Bilbao'],
#  ['',
#   'Gorka Guruzeta',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Athletic Bilbao'],
#  ['',
#   'David Soria',
#   'Goalkeeper',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$8.80m',
#   'Getafe CF'],
#  ['',
#   'Kiko Casilla',
#   'Goalkeeper',
#   '36',
#   '',
#   'Jun 30, 2023',
#   '$770Th.',
#   'Getafe CF'],
#  ['',
#   'Diego Conde',
#   'Goalkeeper',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$330Th.',
#   'Getafe CF'],
#  ['', 'Djené', 'Centre-Back', '30', '', '-', '$8.80m', 'Getafe CF'],
#  ['',
#   'Domingos Duarte',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$8.80m',
#   'Getafe CF'],
#  ['',
#   'Omar Alderete',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$7.70m',
#   'Getafe CF'],
#  ['',
#   'Gastón Álvarez',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Getafe CF'],
#  ['',
#   'Stefan Mitrović',
#   'Centre-Back',
#   '32',
#   '',
#   'Jun 30, 2024',
#   '$1.98m',
#   'Getafe CF'],
#  ['',
#   'Jordan Amavi',
#   'Left-Back',
#   '28',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Getafe CF'],
#  ['',
#   'Fabrizio Angileri',
#   'Left-Back',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Getafe CF'],
#  ['',
#   'Juan Iglesias',
#   'Right-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$2.75m',
#   'Getafe CF'],
#  ['',
#   'Damián Suárez',
#   'Right-Back',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Getafe CF'],
#  ['',
#   'Nemanja Maksimović',
#   'Defensive Midfield',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$13.20m',
#   'Getafe CF'],
#  ['',
#   'Mauro Arambarri',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2023',
#   '$16.50m',
#   'Getafe CF'],
#  ['',
#   'Carles Aleñá',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$9.90m',
#   'Getafe CF'],
#  ['',
#   'Luis Milla',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$4.40m',
#   'Getafe CF'],
#  ['',
#   'Jaime Seoane',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Getafe CF'],
#  ['',
#   'Ángel Algobia',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$550Th.',
#   'Getafe CF'],
#  ['',
#   'Portu',
#   'Right Winger',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'Getafe CF'],
#  ['',
#   'Enes Ünal',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$27.50m',
#   'Getafe CF'],
#  ['',
#   'Borja Mayoral',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2027',
#   '$9.90m',
#   'Getafe CF'],
#  ['',
#   'Munir El Haddadi',
#   'Centre-Forward',
#   '27',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'Getafe CF'],
#  ['',
#   'Jaime Mata',
#   'Centre-Forward',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Getafe CF'],
#  ['',
#   'Juanmi Latasa',
#   'Centre-Forward',
#   '21',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Getafe CF'],
#  ['',
#   'Agustín Marchesín',
#   'Goalkeeper',
#   '34',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Celta de Vigo'],
#  ['',
#   'Iván Villar',
#   'Goalkeeper',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$1.32m',
#   'Celta de Vigo'],
#  ['',
#   'Unai Núñez',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$9.90m',
#   'Celta de Vigo'],
#  ['',
#   'Joseph Aidoo',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$7.70m',
#   'Celta de Vigo'],
#  ['',
#   'Óscar Mingueza',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Celta de Vigo'],
#  ['',
#   'Carlos Domínguez',
#   'Centre-Back',
#   '21',
#   '',
#   'Jun 30, 2026',
#   '$1.10m',
#   'Celta de Vigo'],
#  ['',
#   'Javi Galán',
#   'Left-Back',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$13.20m',
#   'Celta de Vigo'],
#  ['',
#   'Hugo Mallo',
#   'Right-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Celta de Vigo'],
#  ['',
#   'Kevin Vázquez',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Celta de Vigo'],
#  ['',
#   'Renato Tapia',
#   'Defensive Midfield',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$11.00m',
#   'Celta de Vigo'],
#  ['',
#   'Fran Beltrán',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$16.50m',
#   'Celta de Vigo'],
#  ['',
#   'Williot Swedberg',
#   'Central Midfield',
#   '18',
#   '',
#   'Jun 30, 2027',
#   '$5.50m',
#   'Celta de Vigo'],
#  ['',
#   'Luca de la Torre',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$2.20m',
#   'Celta de Vigo'],
#  ['',
#   'Óscar Rodríguez',
#   'Attacking Midfield',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$9.90m',
#   'Celta de Vigo'],
#  ['',
#   'Denis Suárez',
#   'Attacking Midfield',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Celta de Vigo'],
#  ['',
#   'Gabri Veiga',
#   'Attacking Midfield',
#   '20',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Celta de Vigo'],
#  ['',
#   'Franco Cervi',
#   'Left Winger',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$5.50m',
#   'Celta de Vigo'],
#  ['',
#   'Carles Pérez',
#   'Right Winger',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'Celta de Vigo'],
#  ['',
#   'Augusto Solari',
#   'Right Winger',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Celta de Vigo'],
#  ['',
#   'Jörgen Strand Larsen',
#   'Centre-Forward',
#   '22',
#   '',
#   'Jun 30, 2028',
#   '$12.10m',
#   'Celta de Vigo'],
#  ['',
#   'Iago Aspas',
#   'Centre-Forward',
#   '35',
#   '',
#   'Jun 30, 2025',
#   '$7.70m',
#   'Celta de Vigo'],
#  ['',
#   'Gonçalo Paciência',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Celta de Vigo'],
#  ['', 'Sergio Herrera', 'Goalkeeper', '29', '', '-', '$8.80m', 'CA Osasuna'],
#  ['',
#   'Aitor Fernández',
#   'Goalkeeper',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'CA Osasuna'],
#  ['',
#   'Juan Pérez',
#   'Goalkeeper',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$660Th.',
#   'CA Osasuna'],
#  ['',
#   'David García',
#   'Centre-Back',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$22.00m',
#   'CA Osasuna'],
#  ['',
#   'Unai García',
#   'Centre-Back',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'CA Osasuna'],
#  ['',
#   'Aridane Hernández',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'CA Osasuna'],
#  ['',
#   'Manu Sánchez',
#   'Left-Back',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$11.00m',
#   'CA Osasuna'],
#  ['',
#   'Juan Cruz',
#   'Left-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'CA Osasuna'],
#  ['',
#   'Nacho Vidal',
#   'Right-Back',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'CA Osasuna'],
#  ['',
#   'Rubén Peña',
#   'Right-Back',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'CA Osasuna'],
#  ['',
#   'Lucas Torró',
#   'Defensive Midfield',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$5.50m',
#   'CA Osasuna'],
#  ['',
#   'Jon Moncayola',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2031',
#   '$13.20m',
#   'CA Osasuna'],
#  ['',
#   'Darko Brasanac',
#   'Central Midfield',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'CA Osasuna'],
#  ['',
#   'Pablo Ibáñez',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$440Th.',
#   'CA Osasuna'],
#  ['',
#   'Roberto Torres',
#   'Attacking Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'CA Osasuna'],
#  ['',
#   'Aimar Oroz',
#   'Attacking Midfield',
#   '20',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'CA Osasuna'],
#  ['',
#   'Ez Abde',
#   'Left Winger',
#   '20',
#   '',
#   'Jun 30, 2023',
#   '$8.80m',
#   'CA Osasuna'],
#  ['',
#   'Rubén García',
#   'Left Winger',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$8.80m',
#   'CA Osasuna'],
#  ['',
#   'Moi Gómez',
#   'Left Winger',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$8.80m',
#   'CA Osasuna'],
#  ['',
#   'Kike Saverio',
#   'Left Winger',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$220Th.',
#   'CA Osasuna'],
#  ['',
#   'Kike Barja',
#   'Right Winger',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'CA Osasuna'],
#  ['',
#   'Chimy Ávila',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$11.00m',
#   'CA Osasuna'],
#  ['',
#   'Ante Budimir',
#   'Centre-Forward',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'CA Osasuna'],
#  ['',
#   'Kike García',
#   'Centre-Forward',
#   '32',
#   '',
#   'Jun 30, 2024',
#   '$1.98m',
#   'CA Osasuna'],
#  ['',
#   'Benjamin Lecomte',
#   'Goalkeeper',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Álvaro Fernández',
#   'Goalkeeper',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Joan García',
#   'Goalkeeper',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$440Th.',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Leandro Cabrera',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Sergi Gómez',
#   'Centre-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Fernando Calero',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$1.98m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Adrià Pedrosa',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$7.70m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Brian Oliván',
#   'Left-Back',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Óscar Gil',
#   'Right-Back',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Aleix Vidal',
#   'Right-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Vinicius Souza',
#   'Defensive Midfield',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$4.95m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Sergi Darder',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$15.40m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Keidi Bare',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Edu Expósito',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2027',
#   '$4.40m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Pol Lozano',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Javi Puado',
#   'Left Winger',
#   '24',
#   '',
#   'Jun 30, 2025',
#   '$8.80m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Nico Melamed',
#   'Left Winger',
#   '21',
#   '',
#   'Jun 30, 2024',
#   '$8.25m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'José Carlos Lazo',
#   'Left Winger',
#   '26',
#   '',
#   'Jun 30, 2027',
#   '$2.75m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Martin Braithwaite',
#   'Centre-Forward',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Joselu',
#   'Centre-Forward',
#   '32',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Dani Gómez',
#   'Centre-Forward',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'RCD Espanyol Barcelona'],
#  ['',
#   'Paulo Gazzaniga',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Girona FC'],
#  ['',
#   'Juan Carlos',
#   'Goalkeeper',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$330Th.',
#   'Girona FC'],
#  ['',
#   'Toni Fuidias',
#   'Goalkeeper',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$330Th.',
#   'Girona FC'],
#  ['',
#   'Santiago Bueno',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Girona FC'],
#  ['',
#   'David López',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.98m',
#   'Girona FC'],
#  ['',
#   'Bernardo Espinosa',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Girona FC'],
#  ['',
#   'Juanpe',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Girona FC'],
#  ['',
#   'Miguel Gutiérrez',
#   'Left-Back',
#   '21',
#   '',
#   'Jun 30, 2027',
#   '$8.80m',
#   'Girona FC'],
#  ['',
#   'Javi Hernández',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Girona FC'],
#  ['',
#   'Arnau Martínez',
#   'Right-Back',
#   '19',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'Girona FC'],
#  ['',
#   'Yan Couto',
#   'Right-Back',
#   '20',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Girona FC'],
#  ['',
#   'Oriol Romeu',
#   'Defensive Midfield',
#   '31',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Girona FC'],
#  ['',
#   'Ramón Terrats',
#   'Defensive Midfield',
#   '22',
#   '',
#   'Jun 30, 2024',
#   '$1.10m',
#   'Girona FC'],
#  ['',
#   'Ibrahima Kébé',
#   'Defensive Midfield',
#   '22',
#   '',
#   'Jun 30, 2024',
#   '$660Th.',
#   'Girona FC'],
#  ['',
#   'Yangel Herrera',
#   'Central Midfield',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$15.40m',
#   'Girona FC'],
#  ['',
#   'Aleix García',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Girona FC'],
#  ['',
#   'Reinier',
#   'Attacking Midfield',
#   '20',
#   '',
#   'Jun 30, 2023',
#   '$8.80m',
#   'Girona FC'],
#  ['',
#   'Borja García',
#   'Attacking Midfield',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Girona FC'],
#  ['',
#   'Iván Martín',
#   'Attacking Midfield',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Girona FC'],
#  ['',
#   'Manu Vallejo',
#   'Left Winger',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Girona FC'],
#  ['',
#   'Toni Villa',
#   'Left Winger',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'Girona FC'],
#  ['',
#   'Samu Saiz',
#   'Left Winger',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Girona FC'],
#  ['',
#   'Rodrigo Riquelme',
#   'Right Winger',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Girona FC'],
#  ['',
#   'Valery Fernández',
#   'Right Winger',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Girona FC'],
#  ['',
#   'Taty Castellanos',
#   'Centre-Forward',
#   '24',
#   '',
#   'Jun 30, 2023',
#   '$13.20m',
#   'Girona FC'],
#  ['',
#   'Cristhian Stuani',
#   'Centre-Forward',
#   '36',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'Girona FC'],
#  ['',
#   'Fernando Pacheco',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'UD Almería'],
#  ['',
#   'Fernando Martínez',
#   'Goalkeeper',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'UD Almería'],
#  ['',
#   'Diego Fuoli',
#   'Goalkeeper',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$220Th.',
#   'UD Almería'],
#  ['',
#   'Kaiky',
#   'Centre-Back',
#   '18',
#   '',
#   'Jun 30, 2028',
#   '$8.80m',
#   'UD Almería'],
#  ['',
#   'Rodrigo Ely',
#   'Centre-Back',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'UD Almería'],
#  ['',
#   'Srdjan Babic',
#   'Centre-Back',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'UD Almería'],
#  ['',
#   'Chumi',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2025',
#   '$2.20m',
#   'UD Almería'],
#  ['',
#   'Iván Martos',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$440Th.',
#   'UD Almería'],
#  ['',
#   'Sergio Akieme',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'UD Almería'],
#  ['',
#   'Álex Centelles',
#   'Left-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'UD Almería'],
#  ['',
#   'Alejandro Pozo',
#   'Right-Back',
#   '23',
#   '',
#   'Jun 30, 2027',
#   '$4.40m',
#   'UD Almería'],
#  ['',
#   'Houboulang Mendes',
#   'Right-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'UD Almería'],
#  ['',
#   'Juanjo Nieto',
#   'Right-Back',
#   '28',
#   '',
#   'Jun 30, 2023',
#   '$770Th.',
#   'UD Almería'],
#  ['',
#   'Samú Costa',
#   'Defensive Midfield',
#   '21',
#   '',
#   'Jun 30, 2026',
#   '$6.60m',
#   'UD Almería'],
#  ['',
#   'Iñigo Eguaras',
#   'Defensive Midfield',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$1.10m',
#   'UD Almería'],
#  ['',
#   'Gonzalo Melero',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2026',
#   '$4.40m',
#   'UD Almería'],
#  ['',
#   'Lucas Robertone',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'UD Almería'],
#  ['',
#   'Arnau Puigmal',
#   'Central Midfield',
#   '21',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'UD Almería'],
#  ['',
#   'Gui Guedes',
#   'Central Midfield',
#   '20',
#   '',
#   'Jun 30, 2028',
#   '$1.65m',
#   'UD Almería'],
#  ['',
#   'César de la Hoz',
#   'Central Midfield',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'UD Almería'],
#  ['',
#   'Largie Ramazani',
#   'Left Winger',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$11.00m',
#   'UD Almería'],
#  ['',
#   'Lázaro',
#   'Left Winger',
#   '20',
#   '',
#   'Jun 30, 2028',
#   '$7.70m',
#   'UD Almería'],
#  ['',
#   'Adrián Embarba',
#   'Right Winger',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$4.40m',
#   'UD Almería'],
#  ['',
#   'Francisco Portillo',
#   'Right Winger',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'UD Almería'],
#  ['',
#   'Léo Baptistão',
#   'Second Striker',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'UD Almería'],
#  ['',
#   'El Bilal Touré',
#   'Centre-Forward',
#   '21',
#   '',
#   'Jun 30, 2028',
#   '$7.15m',
#   'UD Almería'],
#  ['',
#   'Marko Milovanovic',
#   'Centre-Forward',
#   '19',
#   '',
#   'Jun 30, 2028',
#   '$1.32m',
#   'UD Almería'],
#  ['',
#   'Dyego Sousa',
#   'Centre-Forward',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$1.10m',
#   'UD Almería'],
#  ['',
#   'Stole Dimitrievski',
#   'Goalkeeper',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Miguel Ángel Morro',
#   'Goalkeeper',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$660Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Diego López',
#   'Goalkeeper',
#   '40',
#   '',
#   'Jun 30, 2023',
#   '$550Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Alejandro Catena',
#   'Centre-Back',
#   '28',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Abdul Mumin',
#   'Centre-Back',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Rayo Vallecano'],
#  ['',
#   'Florian Lejeune',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Rayo Vallecano'],
#  ['',
#   'Esteban Saveljich',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Mario Suárez',
#   'Centre-Back',
#   '35',
#   '',
#   'Jun 30, 2023',
#   '$330Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Fran García',
#   'Left-Back',
#   '23',
#   '',
#   'Jun 30, 2025',
#   '$8.25m',
#   'Rayo Vallecano'],
#  ['',
#   'Pep Chavarría',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2027',
#   '$880Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Iván Balliu',
#   'Right-Back',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$2.20m',
#   'Rayo Vallecano'],
#  ['',
#   'Mario Hernández',
#   'Right-Back',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Santi Comesaña',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Unai López',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Pathé Ciss',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Óscar Valentín',
#   'Central Midfield',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Rayo Vallecano'],
#  ['',
#   'Randy Nteka',
#   'Attacking Midfield',
#   '24',
#   '',
#   'Jun 30, 2026',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Óscar Trejo',
#   'Attacking Midfield',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Rayo Vallecano'],
#  ['',
#   'José Pozo',
#   'Attacking Midfield',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'Rayo Vallecano'],
#  ['',
#   'Álvaro García',
#   'Left Winger',
#   '30',
#   '',
#   'Jun 30, 2026',
#   '$6.60m',
#   'Rayo Vallecano'],
#  ['',
#   'Bebé',
#   'Left Winger',
#   '32',
#   '',
#   'Jun 30, 2025',
#   '$880Th.',
#   'Rayo Vallecano'],
#  ['',
#   'Isi Palazón',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Rayo Vallecano'],
#  ['',
#   'Salvi Sánchez',
#   'Right Winger',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Rayo Vallecano'],
#  ['',
#   'Raúl de Tomás',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$13.20m',
#   'Rayo Vallecano'],
#  ['',
#   'Sergio Camello',
#   'Centre-Forward',
#   '21',
#   '',
#   'Jun 30, 2023',
#   '$4.40m',
#   'Rayo Vallecano'],
#  ['',
#   'Radamel Falcao',
#   'Centre-Forward',
#   '36',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Rayo Vallecano'],
#  ['',
#   'Andrés Martín',
#   'Centre-Forward',
#   '23',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'Rayo Vallecano'],
#  ['',
#   'Édgar Badía',
#   'Goalkeeper',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Elche CF'],
#  ['',
#   'Axel Werner',
#   'Goalkeeper',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Elche CF'],
#  ['',
#   'Enzo Roco',
#   'Centre-Back',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'Elche CF'],
#  ['',
#   'Diego González',
#   'Centre-Back',
#   '27',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Elche CF'],
#  ['',
#   'Federico Fernández',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Elche CF'],
#  ['',
#   'Pedro Bigas',
#   'Centre-Back',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Elche CF'],
#  ['',
#   'Gonzalo Verdú',
#   'Centre-Back',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$770Th.',
#   'Elche CF'],
#  ['',
#   'John Nwankwo',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2025',
#   '$440Th.',
#   'Elche CF'],
#  ['',
#   'Nicolás Fernández Mercau',
#   'Left-Back',
#   '22',
#   '',
#   'Jun 30, 2027',
#   '$2.75m',
#   'Elche CF'],
#  ['',
#   'Carlos Clerc',
#   'Left-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Elche CF'],
#  ['',
#   'Pol Lirola',
#   'Right-Back',
#   '25',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'Elche CF'],
#  ['',
#   'Helibelton Palacios',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$1.32m',
#   'Elche CF'],
#  ['',
#   'Omar Mascarell',
#   'Defensive Midfield',
#   '29',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Elche CF'],
#  ['',
#   'Gerard Gumbau',
#   'Defensive Midfield',
#   '27',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Elche CF'],
#  ['',
#   'Raúl Guti',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Elche CF'],
#  ['',
#   'Domingos Quina',
#   'Central Midfield',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$2.42m',
#   'Elche CF'],
#  ['',
#   'Javier Pastore',
#   'Attacking Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$990Th.',
#   'Elche CF'],
#  ['',
#   'Pere Milla',
#   'Left Winger',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Elche CF'],
#  ['',
#   'Tete Morente',
#   'Left Winger',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$3.30m',
#   'Elche CF'],
#  ['', 'Fidel', 'Left Winger', '33', '', 'Jun 30, 2024', '$2.20m', 'Elche CF'],
#  ['',
#   'Álex Collado',
#   'Right Winger',
#   '23',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Elche CF'],
#  ['', 'Josan', 'Right Winger', '32', '', 'Jun 30, 2023', '$1.10m', 'Elche CF'],
#  ['',
#   'Lucas Boyé',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$13.20m',
#   'Elche CF'],
#  ['',
#   'Ezequiel Ponce',
#   'Centre-Forward',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'Elche CF'],
#  ['',
#   'Roger Martí',
#   'Centre-Forward',
#   '31',
#   '',
#   'Jun 30, 2026',
#   '$4.40m',
#   'Elche CF'],
#  ['',
#   'Predrag Rajković',
#   'Goalkeeper',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$9.90m',
#   'RCD Mallorca'],
#  ['',
#   'Dominik Greif',
#   'Goalkeeper',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$2.20m',
#   'RCD Mallorca'],
#  ['',
#   'Leo Román',
#   'Goalkeeper',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$330Th.',
#   'RCD Mallorca'],
#  ['',
#   'Martin Valjent',
#   'Centre-Back',
#   '26',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'RCD Mallorca'],
#  ['',
#   'Antonio Raíllo',
#   'Centre-Back',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'RCD Mallorca'],
#  ['',
#   'Matija Nastasić',
#   'Centre-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'RCD Mallorca'],
#  ['',
#   'Franco Russo',
#   'Centre-Back',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'José Copete',
#   'Centre-Back',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'Braian Cufré',
#   'Left-Back',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'Jaume Costa',
#   'Left-Back',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'Pablo Maffeo',
#   'Right-Back',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$5.50m',
#   'RCD Mallorca'],
#  ['',
#   'Giovanni González',
#   'Right-Back',
#   '28',
#   '',
#   'Jun 30, 2024',
#   '$1.65m',
#   'RCD Mallorca'],
#  ['',
#   'Rodrigo Battaglia',
#   'Defensive Midfield',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$1.98m',
#   'RCD Mallorca'],
#  ['',
#   'Iddrisu Baba',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$3.85m',
#   'RCD Mallorca'],
#  ['',
#   'Iñigo Ruiz de Galarreta',
#   'Central Midfield',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$1.98m',
#   'RCD Mallorca'],
#  ['',
#   'Antonio Sánchez',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2024',
#   '$1.65m',
#   'RCD Mallorca'],
#  ['',
#   'Clément Grenier',
#   'Central Midfield',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$1.10m',
#   'RCD Mallorca'],
#  ['',
#   'Kang-in Lee',
#   'Attacking Midfield',
#   '21',
#   '',
#   'Jun 30, 2025',
#   '$9.90m',
#   'RCD Mallorca'],
#  ['',
#   'Dani Rodríguez',
#   'Attacking Midfield',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'Amath Ndiaye',
#   'Left Winger',
#   '26',
#   '',
#   'Jun 30, 2025',
#   '$2.20m',
#   'RCD Mallorca'],
#  ['',
#   'Lago Júnior',
#   'Left Winger',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$1.32m',
#   'RCD Mallorca'],
#  ['',
#   'Vedat Muriqi',
#   'Centre-Forward',
#   '28',
#   '',
#   'Jun 30, 2027',
#   '$9.90m',
#   'RCD Mallorca'],
#  ['',
#   'Tino Kadewere',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$6.60m',
#   'RCD Mallorca'],
#  ['',
#   'Ángel Rodríguez',
#   'Centre-Forward',
#   '35',
#   '',
#   'Jun 30, 2023',
#   '$2.20m',
#   'RCD Mallorca'],
#  ['',
#   'Abdón Prats',
#   'Centre-Forward',
#   '29',
#   '',
#   'Jun 30, 2024',
#   '$1.65m',
#   'RCD Mallorca'],
#  ['',
#   'Sergio Asenjo',
#   'Goalkeeper',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$4.40m',
#   'Real Valladolid CF'],
#  ['',
#   'Jordi Masip',
#   'Goalkeeper',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$770Th.',
#   'Real Valladolid CF'],
#  ['',
#   'Joaquín Fernández',
#   'Centre-Back',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$3.08m',
#   'Real Valladolid CF'],
#  ['',
#   'Zouhair Feddal',
#   'Centre-Back',
#   '32',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Javi Sánchez',
#   'Centre-Back',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Jawad El Yamiq',
#   'Centre-Back',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'Real Valladolid CF'],
#  ['',
#   'Lucas Olaza',
#   'Left-Back',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Sergio Escudero',
#   'Left-Back',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$1.98m',
#   'Real Valladolid CF'],
#  ['',
#   'Luis Pérez',
#   'Right-Back',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$1.65m',
#   'Real Valladolid CF'],
#  ['',
#   'Iván Fresneda',
#   'Right-Back',
#   '18',
#   '',
#   'Jun 30, 2025',
#   '$1.10m',
#   'Real Valladolid CF'],
#  ['',
#   'Lucas Rosa',
#   'Right-Back',
#   '22',
#   '',
#   'Jun 30, 2025',
#   '$165Th.',
#   'Real Valladolid CF'],
#  ['',
#   'Mickaël Malsa',
#   'Defensive Midfield',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Real Valladolid CF'],
#  ['',
#   'Monchu',
#   'Central Midfield',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$3.30m',
#   'Real Valladolid CF'],
#  ['',
#   'Kike Pérez',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2025',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Álvaro Aguado',
#   'Central Midfield',
#   '26',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Roque Mesa',
#   'Central Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Anuar',
#   'Central Midfield',
#   '27',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Real Valladolid CF'],
#  ['',
#   'Kenedy',
#   'Left Winger',
#   '26',
#   '',
#   'Jun 30, 2027',
#   '$7.70m',
#   'Real Valladolid CF'],
#  ['',
#   'Gonzalo Plata',
#   'Right Winger',
#   '22',
#   '',
#   'Jun 30, 2027',
#   '$6.60m',
#   'Real Valladolid CF'],
#  ['',
#   'Óscar Plano',
#   'Right Winger',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Real Valladolid CF'],
#  ['',
#   'Iván Sánchez',
#   'Right Winger',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$880Th.',
#   'Real Valladolid CF'],
#  ['',
#   'Shon Weissman',
#   'Centre-Forward',
#   '26',
#   '',
#   'Jun 30, 2024',
#   '$8.80m',
#   'Real Valladolid CF'],
#  ['',
#   'Sergi Guardiola',
#   'Centre-Forward',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Real Valladolid CF'],
#  ['',
#   'Juanjo Narváez',
#   'Centre-Forward',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$1.65m',
#   'Real Valladolid CF'],
#  ['',
#   'Sergio León',
#   'Centre-Forward',
#   '33',
#   '',
#   'Jun 30, 2024',
#   '$1.32m',
#   'Real Valladolid CF'],
#  ['',
#   'Jeremías Ledesma',
#   'Goalkeeper',
#   '29',
#   '',
#   'Jun 30, 2025',
#   '$6.60m',
#   'Cádiz CF'],
#  ['',
#   'David Gil',
#   'Goalkeeper',
#   '28',
#   '',
#   'Jun 30, 2025',
#   '$880Th.',
#   'Cádiz CF'],
#  ['', 'Fali', 'Centre-Back', '29', '', 'Jun 30, 2024', '$2.75m', 'Cádiz CF'],
#  ['',
#   'Víctor Chust',
#   'Centre-Back',
#   '22',
#   '',
#   'Jun 30, 2026',
#   '$2.75m',
#   'Cádiz CF'],
#  ['',
#   'Juan Cala',
#   'Centre-Back',
#   '32',
#   '',
#   'Jun 30, 2024',
#   '$990Th.',
#   'Cádiz CF'],
#  ['',
#   'Luis Hernández',
#   'Centre-Back',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$880Th.',
#   'Cádiz CF'],
#  ['',
#   'Momo Mbaye',
#   'Centre-Back',
#   '24',
#   '',
#   'Jun 30, 2024',
#   '$440Th.',
#   'Cádiz CF'],
#  ['',
#   'Alfonso Espino',
#   'Left-Back',
#   '30',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Cádiz CF'],
#  ['',
#   'Santiago Arzamendia',
#   'Left-Back',
#   '24',
#   '',
#   'Jun 30, 2025',
#   '$1.98m',
#   'Cádiz CF'],
#  ['',
#   'Joseba Zaldua',
#   'Right-Back',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$4.40m',
#   'Cádiz CF'],
#  ['',
#   'Iza Carcelén',
#   'Right-Back',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Cádiz CF'],
#  ['',
#   'Antonio Blanco',
#   'Defensive Midfield',
#   '22',
#   '',
#   'Jun 30, 2023',
#   '$5.50m',
#   'Cádiz CF'],
#  ['',
#   'Tomás Alarcón',
#   'Defensive Midfield',
#   '23',
#   '',
#   'Jun 30, 2025',
#   '$3.30m',
#   'Cádiz CF'],
#  ['',
#   'Jon Ander Garrido',
#   'Defensive Midfield',
#   '33',
#   '',
#   'Jun 30, 2023',
#   '$440Th.',
#   'Cádiz CF'],
#  ['',
#   'José Mari',
#   'Defensive Midfield',
#   '34',
#   '',
#   'Jun 30, 2024',
#   '$440Th.',
#   'Cádiz CF'],
#  ['',
#   'Rubén Alcaraz',
#   'Central Midfield',
#   '31',
#   '',
#   'Jun 30, 2024',
#   '$2.75m',
#   'Cádiz CF'],
#  ['',
#   'Fede San Emeterio',
#   'Central Midfield',
#   '25',
#   '',
#   'Jun 30, 2026',
#   '$1.65m',
#   'Cádiz CF'],
#  ['',
#   'Álex Fernández',
#   'Attacking Midfield',
#   '30',
#   '',
#   'Jun 30, 2025',
#   '$5.50m',
#   'Cádiz CF'],
#  ['',
#   'Théo Bongonda',
#   'Left Winger',
#   '26',
#   '',
#   'Jun 30, 2026',
#   '$6.60m',
#   'Cádiz CF'],
#  ['',
#   'Awer Mabil',
#   'Left Winger',
#   '27',
#   '',
#   'Jun 30, 2026',
#   '$1.98m',
#   'Cádiz CF'],
#  ['',
#   'Brian Ocampo',
#   'Right Winger',
#   '23',
#   '',
#   'Jun 30, 2026',
#   '$2.20m',
#   'Cádiz CF'],
#  ['',
#   'Iván Alejo',
#   'Right Winger',
#   '27',
#   '',
#   'Jun 30, 2025',
#   '$1.32m',
#   'Cádiz CF'],
#  ['',
#   'Choco Lozano',
#   'Centre-Forward',
#   '29',
#   '',
#   'Jun 30, 2023',
#   '$3.30m',
#   'Cádiz CF'],
#  ['',
#   'Lucas Pérez',
#   'Centre-Forward',
#   '34',
#   '',
#   'Jun 30, 2023',
#   '$2.75m',
#   'Cádiz CF'],
#  ['',
#   'Rubén Sobrino',
#   'Centre-Forward',
#   '30',
#   '',
#   'Jun 30, 2024',
#   '$2.20m',
#   'Cádiz CF'],
#  ['',
#   'Álvaro Negredo',
#   'Centre-Forward',
#   '37',
#   '',
#   'Jun 30, 2023',
#   '$1.65m',
#   'Cádiz CF'],
#  ['',
#   'Álvaro Giménez',
#   'Centre-Forward',
#   '31',
#   '',
#   'Jun 30, 2023',
#   '$1.10m',
#   'Cádiz CF']]

# %% [markdown]
# Now, we create the pandas dataframe for the players

# %%
# creating the pandas dataframe for the list of lists
players_df = pd.DataFrame(players)
players_df.columns = ["Kit No.", "Name", "Position", "Age", "Nationality", "Contract End", "Market Value", "Team"]

# %% [markdown]
# And we will drop the columsn which are completely empty-the kit numbers and nationalities.

# %%
# dropping these null columns
players_df = players_df.drop(["Kit No.", "Nationality"], axis=1)

# %%
players_df.head()
# Out:
#                Name     Position Age  Contract End Market Value         Team
# 0  Thibaut Courtois   Goalkeeper  30  Jun 30, 2026      $66.00m  Real Madrid
# 1      Andriy Lunin   Goalkeeper  23  Jun 30, 2024       $2.75m  Real Madrid
# 2      Éder Militão  Centre-Back  24  Jun 30, 2025      $66.00m  Real Madrid
# 3       David Alaba  Centre-Back  30  Jun 30, 2026      $60.50m  Real Madrid
# 4   Antonio Rüdiger  Centre-Back  29  Jun 30, 2026      $44.00m  Real Madrid

# %% [markdown]
# We then format the Market Values of the players from strings to floating point numbers, and switch age to be a numeric value.

# %%
# now, getting the market values formatted
players_df["Market Value"] = players_df["Market Value"].apply(str_to_float)
# changing the age column's datatype to numeric
players_df["Age"] = players_df["Age"].apply(pd.to_numeric)

# %%
# checking the datatypes
players_df.dtypes
# Out:
# Name             object
# Position         object
# Age               int64
# Contract End     object
# Market Value    float64
# Team             object
# dtype: object

# %%
# getting all the positions and the number of players that play in them
players_df["Position"].value_counts()
# Out:
# Centre-Back           87
# Central Midfield      73
# Centre-Forward        66
# Goalkeeper            52
# Right-Back            44
# Left-Back             41
# Left Winger           37
# Right Winger          36
# Defensive Midfield    32
# Attacking Midfield    25
# Second Striker         3
# Right Midfield         1
# Name: Position, dtype: int64

# %%
# checking whether there are any non-unique player names
pvc = players_df["Name"].value_counts()
pvc[pvc > 1]
# Out:
# Series([], Name: Name, dtype: int64)

# %% [markdown]
# Now, we will focus on creating the optimal schema structure that this solution requires.
# We know that the `clubs` table has the club name as the `primary key`.
#
# The players table can have the player `name` as a `primary key`, with `team` being a `foreign key` reference to `clubs`.
#
# Noting that we need to obtain a more generalised notion of position, I will create an auxilliary `Position_Map` Table, containing the mappings for each position to its more `general_position`. I am making the assumption that *wingers are an attacking position*, and thus will be classified as forwards. This means that `Position` will be a `foreign key` reference to `Position_Map`'s `Position`.

# %% [markdown]
# We will use the `sqlite3` module on python and run a local `sqlite` database instance on memory for this project.

# %%
# for the player position table
# we get the unique position values
players_df_position = players_df.loc[:, ["Position"]].copy().drop_duplicates()

# %%
# creating the function to generate the respective general position
def get_gen_pos(pos):
  # coercing to lowercase for easier analysis
  pos = pos.lower()
  # for goalkeeper
  if pos == "goalkeeper":
    return "Goalkeepers"
  elif "back" in pos:
    return "Defenders"
  elif "midfield" in pos:
    return "Midfielders"
  else:
    return "Forwards"

# %%
# creating the position map dataframe
players_df_position["general_position"] = players_df_position["Position"].apply(get_gen_pos)
players_df_position = players_df_position.reset_index().drop(["index"], axis=1)

# %%
players_df_position
# Out:
#               Position general_position
# 0           Goalkeeper      Goalkeepers
# 1          Centre-Back        Defenders
# 2            Left-Back        Defenders
# 3           Right-Back        Defenders
# 4   Defensive Midfield      Midfielders
# 5     Central Midfield      Midfielders
# 6          Left Winger         Forwards
# 7         Right Winger         Forwards
# 8       Centre-Forward         Forwards
# 9   Attacking Midfield      Midfielders
# 10      Second Striker         Forwards
# 11      Right Midfield      Midfielders

# %% [markdown]
# Now, we proceed to save these 3 tables to our database schema, called `footy_schema.db`.
#
# The entity relationship is as normalised as possible, considering the nature of the data and the dependencies. So, it is optimised enough to handle the analytical side of query processing for this project.

# %%
# initialising a local connection for sqlite on the RAM
conn = sqlite3.connect("footy_schema.db")

# initialising the cursor object to query the database tables,
# as mentioned on the sqlite3 documentation
cur = conn.cursor()

# %%
# create table statement for the clubs table
cur.execute("""
CREATE TABLE Clubs
(
  Name VARCHAR(80) PRIMARY KEY NOT NULL,
  Squad INTEGER,
  `Avg Squad Age` FLOAT,
  Foreigners INTEGER,
  `Avg Market Value ($)` DOUBLE,
  `Total Market Value ($)` DOUBLE
);
""")
# create table statement for the position_mapping table
cur.execute("""
CREATE TABLE Position_Map
(
  Position VARCHAR(60) PRIMARY KEY NOT NULL,
  `General Position` VARCHAR(40)
);
""")
# create table statement for the players table
cur.execute("""
CREATE TABLE Players
(
  Name VARCHAR(80) PRIMARY KEY NOT NULL,
  Position REFERENCES Position_Map NOT NULL,
  Age INTEGER,
  `Contract End` INTEGER,
  `Market Value ($)` DOUBLE,
  Team REFERENCES Clubs NOT NULL
);
""")

# %%
# checking that the tables actually are created in the database schema
cur.execute("""
SELECT name from SQLITE_MASTER WHERE type = "table";
""").fetchall()
# EXISTS!
# Out:
# [('Clubs',), ('Position_Map',), ('Players',)]

# %% [markdown]
# Now, we can only insert values as a row tuple using the sqlite3 python API's insert into statements.
# So, we will reformat the pandas dataframe to get a list of row tuples, and run an `executemany()` command to perform a bulk insert.

# %%
# creating the list of row tuples for the clubs table
clubs_list_tuples = list(clubs_df1.itertuples(index=False, name=None))

# performing bulk insert
cur.executemany("INSERT INTO Clubs VALUES(?, ?, ?, ?, ?, ?)", clubs_list_tuples)
# committing changes to database
conn.commit()

# %%
# creating the list of row tuples for the position_mapping table
position_tuples = list(players_df_position.itertuples(index=False, name=None))

# performing bulk insert
cur.executemany("INSERT INTO Position_Map VALUES(?, ?)", position_tuples)
# committing changes to database
conn.commit()

# %%
# creating the list of row tuples for the players table
players_tuples = list(players_df.itertuples(index=False, name=None))

# performing bulk insert
cur.executemany("INSERT INTO Players VALUES(?, ?, ?, ?, ?, ?)", players_tuples)
# committing changes to database
conn.commit()

# %% [markdown]
# Now, we can run our query to get the total market value by team and position for teams in LaLiga 2022-2023.

# %%
# getting the results of the query as a pandas dataframe
qry_df = pd.read_sql_query("""
SELECT P.Team, PM.`General Position` as Position,
SUM(P.`Market Value ($)`) as `Total Market Value ($)`
FROM Players P JOIN Position_Map PM on P.Position = PM.Position
GROUP BY P.Team, PM.`General Position`
""", con=conn)

# %%
# we have 20 teams, with 4 general positions each. So 80 rows in total 
qry_df.shape
# Validated
# Out:
# (80, 3)

# %%
qry_df
# Out:
#                   Team     Position  Total Market Value ($)
# 0      Athletic Bilbao    Defenders              65890000.0
# 1      Athletic Bilbao     Forwards              80850000.0
# 2      Athletic Bilbao  Goalkeepers              33000000.0
# 3      Athletic Bilbao  Midfielders              80850000.0
# 4   Atlético de Madrid    Defenders             168300000.0
# ..                 ...          ...                     ...
# 75         Valencia CF  Midfielders              95700000.0
# 76       Villarreal CF    Defenders             134750000.0
# 77       Villarreal CF     Forwards             191400000.0
# 78       Villarreal CF  Goalkeepers               8470000.0
# 79       Villarreal CF  Midfielders              61600000.0
#
# [80 rows x 3 columns]

# %% [markdown]
# I can create a new table in the database to store the results of this query using a CTE within a `CREATE TABLE` clause. I will also save the results into a CSV, upon displaying its head and tail on this notebook as a pandas dataframe.

# %%
# saving the results of the query into the database,
# into a table called query_results
cur.execute("""
CREATE TABLE Query_Results AS
  SELECT P.Team, PM.`General Position` as Position,
  SUM(P.`Market Value ($)`) as `Total Market Value ($)`
  FROM Players P JOIN Position_Map PM on P.Position = PM.Position
  GROUP BY P.Team, PM.`General Position`
;
""")

# %%
# saving the results as a CSV file for future manipulation
qry_df.to_csv("query_results.csv")

# %%
# to close connection, RUN ONLY THIS STATEMENT
conn.close()

# %% [markdown]
# ## Sanity Checks for the tables in `footy_schema.db`

# %%
# double check whether data tables still saved in database
# initialising a local connection for sqlite on the RAM
conn = sqlite3.connect("footy_schema.db")

# initialising the cursor object to query the database tables,
# as mentioned on the sqlite3 documentation
cur = conn.cursor()

# %%
# checking that the tables actually are created in the database schema
cur.execute("""
SELECT name from SQLITE_MASTER WHERE type = "table";
""").fetchall()
# Out:
# [('Clubs',), ('Position_Map',), ('Players',), ('Query_Results',)]

# %%
# storing all the tables as csvs
pd.read_sql_query("SELECT * FROM Clubs", con=conn).to_csv("clubs.csv")
pd.read_sql_query("SELECT * FROM Position_Map", con=conn).to_csv("position_map.csv")
pd.read_sql_query("SELECT * FROM Players", con=conn).to_csv("players.csv")

# %%
cur.execute("""
SELECT * FROM CLUBS;
""").fetchall()
# Out:
# [('Real Madrid', 23, 27.4, 16, 40050000.0, 921250000.0),
#  ('FC Barcelona', 25, 25.4, 10, 35800000.0, 895070000.0),
#  ('Atlético de Madrid', 22, 27.8, 16, 30580000.0, 672650000.0),
#  ('Real Sociedad', 27, 24.8, 5, 15130000.0, 408430000.0),
#  ('Villarreal CF', 25, 28.0, 11, 15850000.0, 396220000.0),
#  ('Sevilla FC', 25, 28.5, 18, 12170000.0, 304150000.0),
#  ('Real Betis Balompié', 26, 28.8, 12, 11000000.0, 286000000.0),
#  ('Valencia CF', 25, 24.4, 14, 10440000.0, 260920000.00000003),
#  ('Athletic Bilbao', 25, 27.3, 1, 10420000.0, 260589999.99999997),
#  ('Getafe CF', 24, 27.3, 12, 6610000.0, 158730000.0),
#  ('Celta de Vigo', 22, 26.0, 9, 6440000.0, 141570000.0),
#  ('CA Osasuna', 24, 27.6, 5, 5680000.0, 136400000.0),
#  ('RCD Espanyol Barcelona', 21, 26.5, 5, 4830000.0, 101420000.0),
#  ('Girona FC', 26, 26.0, 9, 3880000.0, 100760000.0),
#  ('UD Almería', 28, 25.4, 13, 3420000.0, 95700000.0),
#  ('Rayo Vallecano', 27, 28.1, 10, 3360000.0, 90750000.0),
#  ('Elche CF', 25, 28.0, 9, 3180000.0, 79420000.0),
#  ('RCD Mallorca', 25, 27.8, 15, 3150000.0, 78760000.0),
#  ('Real Valladolid CF', 25, 27.7, 10, 2870000.0, 71670000.0),
#  ('Cádiz CF', 27, 28.6, 9, 2650000.0, 71500000.0)]

# %%
cur.execute("""
SELECT * FROM Position_Map;
""").fetchall()
# Out:
# [('Goalkeeper', 'Goalkeepers'),
#  ('Centre-Back', 'Defenders'),
#  ('Left-Back', 'Defenders'),
#  ('Right-Back', 'Defenders'),
#  ('Defensive Midfield', 'Midfielders'),
#  ('Central Midfield', 'Midfielders'),
#  ('Left Winger', 'Forwards'),
#  ('Right Winger', 'Forwards'),
#  ('Centre-Forward', 'Forwards'),
#  ('Attacking Midfield', 'Midfielders'),
#  ('Second Striker', 'Forwards'),
#  ('Right Midfield', 'Midfielders')]

# %%
cur.execute("""
SELECT * FROM Players;
""").fetchall()
# Out:
# [('Thibaut Courtois',
#   'Goalkeeper',
#   30,
#   'Jun 30, 2026',
#   66000000.0,
#   'Real Madrid'),
#  ('Andriy Lunin', 'Goalkeeper', 23, 'Jun 30, 2024', 2750000.0, 'Real Madrid'),
#  ('Éder Militão',
#   'Centre-Back',
#   24,
#   'Jun 30, 2025',
#   66000000.0,
#   'Real Madrid'),
#  ('David Alaba', 'Centre-Back', 30, 'Jun 30, 2026', 60500000.0, 'Real Madrid'),
#  ('Antonio Rüdiger',
#   'Centre-Back',
#   29,
#   'Jun 30, 2026',
#   44000000.0,
#   'Real Madrid'),
#  ('Nacho Fernández',
#   'Centre-Back',
#   32,
#   'Jun 30, 2023',
#   7700000.0,
#   'Real Madrid'),
#  ('Jesús Vallejo',
#   'Centre-Back',
#   25,
#   'Jun 30, 2025',
#   3300000.0,
#   'Real Madrid'),
#  ('Ferland Mendy', 'Left-Back', 27, 'Jun 30, 2025', 44000000.0, 'Real Madrid'),
#  ('Daniel Carvajal',
#   'Right-Back',
#   30,
#   'Jun 30, 2025',
#   19800000.0,
#   'Real Madrid'),
#  ('Álvaro Odriozola',
#   'Right-Back',
#   26,
#   'Jun 30, 2024',
#   11000000.0,
#   'Real Madrid'),
#  ('Aurélien Tchouameni',
#   'Defensive Midfield',
#   22,
#   'Jun 30, 2028',
#   88000000.0,
#   'Real Madrid'),
#  ('Federico Valverde',
#   'Central Midfield',
#   24,
#   'Jun 30, 2027',
#   88000000.0,
#   'Real Madrid'),
#  ('Eduardo Camavinga',
#   'Central Midfield',
#   19,
#   'Jun 30, 2027',
#   60500000.0,
#   'Real Madrid'),
#  ('Toni Kroos',
#   'Central Midfield',
#   32,
#   'Jun 30, 2023',
#   22000000.0,
#   'Real Madrid'),
#  ('Dani Ceballos',
#   'Central Midfield',
#   26,
#   'Jun 30, 2023',
#   15400000.0,
#   'Real Madrid'),
#  ('Luka Modric',
#   'Central Midfield',
#   37,
#   'Jun 30, 2023',
#   11000000.0,
#   'Real Madrid'),
#  ('Vinicius Junior',
#   'Left Winger',
#   22,
#   'Jun 30, 2024',
#   132000000.0,
#   'Real Madrid'),
#  ('Eden Hazard', 'Left Winger', 31, 'Jun 30, 2024', 13200000.0, 'Real Madrid'),
#  ('Rodrygo', 'Right Winger', 21, 'Jun 30, 2025', 77000000.0, 'Real Madrid'),
#  ('Marco Asensio',
#   'Right Winger',
#   26,
#   'Jun 30, 2023',
#   38500000.0,
#   'Real Madrid'),
#  ('Lucas Vázquez',
#   'Right Winger',
#   31,
#   'Jun 30, 2024',
#   13200000.0,
#   'Real Madrid'),
#  ('Karim Benzema',
#   'Centre-Forward',
#   34,
#   'Jun 30, 2023',
#   33000000.0,
#   'Real Madrid'),
#  ('Mariano Díaz',
#   'Centre-Forward',
#   29,
#   'Jun 30, 2023',
#   4400000.0,
#   'Real Madrid'),
#  ('Marc-André ter Stegen',
#   'Goalkeeper',
#   30,
#   'Jun 30, 2025',
#   33000000.0,
#   'FC Barcelona'),
#  ('Iñaki Peña', 'Goalkeeper', 23, 'Jun 30, 2023', 4620000.0, 'FC Barcelona'),
#  ('Arnau Tenas', 'Goalkeeper', 21, 'Jun 30, 2023', 1650000.0, 'FC Barcelona'),
#  ('Ronald Araújo',
#   'Centre-Back',
#   23,
#   'Jun 30, 2026',
#   66000000.0,
#   'FC Barcelona'),
#  ('Jules Koundé',
#   'Centre-Back',
#   23,
#   'Jun 30, 2027',
#   66000000.0,
#   'FC Barcelona'),
#  ('Andreas Christensen',
#   'Centre-Back',
#   26,
#   'Jun 30, 2026',
#   38500000.0,
#   'FC Barcelona'),
#  ('Eric García',
#   'Centre-Back',
#   21,
#   'Jun 30, 2026',
#   19800000.0,
#   'FC Barcelona'),
#  ('Gerard Piqué',
#   'Centre-Back',
#   35,
#   'Jun 30, 2024',
#   3300000.0,
#   'FC Barcelona'),
#  ('Marcos Alonso',
#   'Left-Back',
#   31,
#   'Jun 30, 2023',
#   13200000.0,
#   'FC Barcelona'),
#  ('Jordi Alba', 'Left-Back', 33, 'Jun 30, 2024', 9900000.0, 'FC Barcelona'),
#  ('Alejandro Balde',
#   'Left-Back',
#   19,
#   'Jun 30, 2024',
#   8800000.0,
#   'FC Barcelona'),
#  ('Héctor Bellerín',
#   'Right-Back',
#   27,
#   'Jun 30, 2023',
#   22000000.0,
#   'FC Barcelona'),
#  ('Sergi Roberto',
#   'Right-Back',
#   30,
#   'Jun 30, 2023',
#   6600000.0,
#   'FC Barcelona'),
#  ('Sergio Busquets',
#   'Defensive Midfield',
#   34,
#   'Jun 30, 2023',
#   9900000.0,
#   'FC Barcelona'),
#  ('Pedri', 'Central Midfield', 19, 'Jun 30, 2026', 99000000.0, 'FC Barcelona'),
#  ('Gavi', 'Central Midfield', 18, 'Jun 30, 2026', 77000000.0, 'FC Barcelona'),
#  ('Frenkie de Jong',
#   'Central Midfield',
#   25,
#   'Jun 30, 2026',
#   66000000.0,
#   'FC Barcelona'),
#  ('Franck Kessié',
#   'Central Midfield',
#   25,
#   'Jun 30, 2026',
#   49500000.0,
#   'FC Barcelona'),
#  ('Pablo Torre',
#   'Attacking Midfield',
#   19,
#   'Jun 30, 2026',
#   3300000.0,
#   'FC Barcelona'),
#  ('Ansu Fati', 'Left Winger', 20, 'Jun 30, 2027', 66000000.0, 'FC Barcelona'),
#  ('Ferran Torres',
#   'Left Winger',
#   22,
#   'Jun 30, 2027',
#   44000000.0,
#   'FC Barcelona'),
#  ('Ousmane Dembélé',
#   'Right Winger',
#   25,
#   'Jun 30, 2024',
#   55000000.0,
#   'FC Barcelona'),
#  ('Raphinha', 'Right Winger', 25, 'Jun 30, 2027', 55000000.0, 'FC Barcelona'),
#  ('Robert Lewandowski',
#   'Centre-Forward',
#   34,
#   'Jun 30, 2026',
#   49500000.0,
#   'FC Barcelona'),
#  ('Memphis Depay',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2023',
#   27500000.0,
#   'FC Barcelona'),
#  ('Jan Oblak',
#   'Goalkeeper',
#   29,
#   'Jun 30, 2028',
#   44000000.0,
#   'Atlético de Madrid'),
#  ('Ivo Grbic',
#   'Goalkeeper',
#   26,
#   'Jun 30, 2024',
#   3850000.0,
#   'Atlético de Madrid'),
#  ('José María Giménez',
#   'Centre-Back',
#   27,
#   'Jun 30, 2025',
#   49500000.0,
#   'Atlético de Madrid'),
#  ('Mario Hermoso',
#   'Centre-Back',
#   27,
#   'Jun 30, 2024',
#   19800000.0,
#   'Atlético de Madrid'),
#  ('Stefan Savic',
#   'Centre-Back',
#   31,
#   'Jun 30, 2024',
#   15400000.0,
#   'Atlético de Madrid'),
#  ('Felipe',
#   'Centre-Back',
#   33,
#   'Jun 30, 2023',
#   6600000.0,
#   'Atlético de Madrid'),
#  ('Sergio Reguilón',
#   'Left-Back',
#   25,
#   'Jun 30, 2023',
#   27500000.0,
#   'Atlético de Madrid'),
#  ('Reinildo Mandava',
#   'Left-Back',
#   28,
#   'Jun 30, 2025',
#   27500000.0,
#   'Atlético de Madrid'),
#  ('Nahuel Molina',
#   'Right-Back',
#   24,
#   'Jun 30, 2027',
#   22000000.0,
#   'Atlético de Madrid'),
#  ('Geoffrey Kondogbia',
#   'Defensive Midfield',
#   29,
#   'Jun 30, 2024',
#   22000000.0,
#   'Atlético de Madrid'),
#  ('Axel Witsel',
#   'Defensive Midfield',
#   33,
#   'Jun 30, 2023',
#   5500000.0,
#   'Atlético de Madrid'),
#  ('Marcos Llorente',
#   'Central Midfield',
#   27,
#   'Jun 30, 2027',
#   44000000.0,
#   'Atlético de Madrid'),
#  ('Rodrigo de Paul',
#   'Central Midfield',
#   28,
#   'Jun 30, 2026',
#   38500000.0,
#   'Atlético de Madrid'),
#  ('Koke',
#   'Central Midfield',
#   30,
#   'Jun 30, 2024',
#   22000000.0,
#   'Atlético de Madrid'),
#  ('Saúl Ñíguez',
#   'Central Midfield',
#   27,
#   'Jun 30, 2026',
#   22000000.0,
#   'Atlético de Madrid'),
#  ('Thomas Lemar',
#   'Attacking Midfield',
#   26,
#   'Jun 30, 2023',
#   38500000.0,
#   'Atlético de Madrid'),
#  ('Yannick Carrasco',
#   'Left Winger',
#   29,
#   'Jun 30, 2024',
#   44000000.0,
#   'Atlético de Madrid'),
#  ('Ángel Correa',
#   'Right Winger',
#   27,
#   'Jun 30, 2026',
#   44000000.0,
#   'Atlético de Madrid'),
#  ('João Félix',
#   'Second Striker',
#   22,
#   'Jun 30, 2026',
#   77000000.0,
#   'Atlético de Madrid'),
#  ('Antoine Griezmann',
#   'Second Striker',
#   31,
#   'Jun 30, 2023',
#   38500000.0,
#   'Atlético de Madrid'),
#  ('Matheus Cunha',
#   'Centre-Forward',
#   23,
#   'Jun 30, 2026',
#   33000000.0,
#   'Atlético de Madrid'),
#  ('Álvaro Morata',
#   'Centre-Forward',
#   30,
#   'Jun 30, 2024',
#   27500000.0,
#   'Atlético de Madrid'),
#  ('Álex Remiro',
#   'Goalkeeper',
#   27,
#   'Jun 30, 2027',
#   24200000.0,
#   'Real Sociedad'),
#  ('Andoni Zubiaurre',
#   'Goalkeeper',
#   25,
#   'Jun 30, 2024',
#   330000.0,
#   'Real Sociedad'),
#  ('Robin Le Normand',
#   'Centre-Back',
#   25,
#   'Jun 30, 2026',
#   38500000.0,
#   'Real Sociedad'),
#  ('Aritz Elustondo',
#   'Centre-Back',
#   28,
#   'Jun 30, 2024',
#   22000000.0,
#   'Real Sociedad'),
#  ('Igor Zubeldia',
#   'Centre-Back',
#   25,
#   'Jun 30, 2024',
#   16500000.0,
#   'Real Sociedad'),
#  ('Jon Pacheco',
#   'Centre-Back',
#   21,
#   'Jun 30, 2027',
#   1100000.0,
#   'Real Sociedad'),
#  ('Aihen Muñoz', 'Left-Back', 25, 'Jun 30, 2024', 6600000.0, 'Real Sociedad'),
#  ('Diego Rico', 'Left-Back', 29, 'Jun 30, 2023', 3300000.0, 'Real Sociedad'),
#  ('Andoni Gorosabel',
#   'Right-Back',
#   26,
#   'Jun 30, 2024',
#   11000000.0,
#   'Real Sociedad'),
#  ('Álex Sola', 'Right-Back', 23, 'Jun 30, 2026', 1650000.0, 'Real Sociedad'),
#  ('Martín Zubimendi',
#   'Defensive Midfield',
#   23,
#   'Jun 30, 2027',
#   38500000.0,
#   'Real Sociedad'),
#  ('Asier Illarramendi',
#   'Defensive Midfield',
#   32,
#   'Jun 30, 2023',
#   3300000.0,
#   'Real Sociedad'),
#  ('Mikel Merino',
#   'Central Midfield',
#   26,
#   'Jun 30, 2025',
#   55000000.0,
#   'Real Sociedad'),
#  ('Ander Guevara',
#   'Central Midfield',
#   25,
#   'Jun 30, 2024',
#   5500000.0,
#   'Real Sociedad'),
#  ('Beñat Turrientes',
#   'Central Midfield',
#   20,
#   'Jun 30, 2027',
#   3300000.0,
#   'Real Sociedad'),
#  ('Brais Méndez',
#   'Right Midfield',
#   25,
#   'Jun 30, 2028',
#   24200000.0,
#   'Real Sociedad'),
#  ('David Silva',
#   'Attacking Midfield',
#   36,
#   'Jun 30, 2023',
#   4400000.0,
#   'Real Sociedad'),
#  ('Robert Navarro',
#   'Attacking Midfield',
#   20,
#   'Jun 30, 2027',
#   3300000.0,
#   'Real Sociedad'),
#  ('Mikel Oyarzabal',
#   'Left Winger',
#   25,
#   'Jun 30, 2024',
#   66000000.0,
#   'Real Sociedad'),
#  ('Ander Barrenetxea',
#   'Left Winger',
#   20,
#   'Jun 30, 2027',
#   9900000.0,
#   'Real Sociedad'),
#  ('Martín Merquelanz',
#   'Left Winger',
#   27,
#   'Jun 30, 2025',
#   1650000.0,
#   'Real Sociedad'),
#  ('Takefusa Kubo',
#   'Right Winger',
#   21,
#   'Jun 30, 2027',
#   9900000.0,
#   'Real Sociedad'),
#  ('Umar Sadiq',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2028',
#   19800000.0,
#   'Real Sociedad'),
#  ('Momo Cho',
#   'Centre-Forward',
#   18,
#   'Jun 30, 2027',
#   16500000.0,
#   'Real Sociedad'),
#  ('Alexander Sörloth',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2023',
#   11000000.0,
#   'Real Sociedad'),
#  ('Carlos Fernández',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2026',
#   5500000.0,
#   'Real Sociedad'),
#  ('Jon Karrikaburu',
#   'Centre-Forward',
#   20,
#   'Jun 30, 2026',
#   5500000.0,
#   'Real Sociedad'),
#  ('Gerónimo Rulli',
#   'Goalkeeper',
#   30,
#   'Jun 30, 2024',
#   6600000.0,
#   'Villarreal CF'),
#  ('Filip Jörgensen',
#   'Goalkeeper',
#   20,
#   'Jun 30, 2025',
#   1100000.0,
#   'Villarreal CF'),
#  ('Pepe Reina', 'Goalkeeper', 40, 'Jun 30, 2023', 770000.0, 'Villarreal CF'),
#  ('Pau Torres',
#   'Centre-Back',
#   25,
#   'Jun 30, 2024',
#   55000000.0,
#   'Villarreal CF'),
#  ('Jorge Cuenca',
#   'Centre-Back',
#   22,
#   'Jun 30, 2025',
#   8800000.0,
#   'Villarreal CF'),
#  ('Aïssa Mandi',
#   'Centre-Back',
#   31,
#   'Jun 30, 2025',
#   6600000.0,
#   'Villarreal CF'),
#  ('Raúl Albiol',
#   'Centre-Back',
#   37,
#   'Jun 30, 2023',
#   3300000.0,
#   'Villarreal CF'),
#  ('Alfonso Pedraza',
#   'Left-Back',
#   26,
#   'Jun 30, 2026',
#   19800000.0,
#   'Villarreal CF'),
#  ('Johan Mojica', 'Left-Back', 30, 'Jun 30, 2026', 5500000.0, 'Villarreal CF'),
#  ('Alberto Moreno',
#   'Left-Back',
#   30,
#   'Jun 30, 2024',
#   5500000.0,
#   'Villarreal CF'),
#  ('Juan Foyth', 'Right-Back', 24, 'Jun 30, 2026', 27500000.0, 'Villarreal CF'),
#  ('Kiko Femenía',
#   'Right-Back',
#   31,
#   'Jun 30, 2025',
#   2750000.0,
#   'Villarreal CF'),
#  ('Francis Coquelin',
#   'Defensive Midfield',
#   31,
#   'Jun 30, 2024',
#   5500000.0,
#   'Villarreal CF'),
#  ('Étienne Capoue',
#   'Defensive Midfield',
#   34,
#   'Jun 30, 2024',
#   3300000.0,
#   'Villarreal CF'),
#  ('Giovani Lo Celso',
#   'Central Midfield',
#   26,
#   'Jun 30, 2023',
#   24200000.0,
#   'Villarreal CF'),
#  ('Manu Trigueros',
#   'Central Midfield',
#   31,
#   'Jun 30, 2025',
#   13200000.0,
#   'Villarreal CF'),
#  ('Dani Parejo',
#   'Central Midfield',
#   33,
#   'Jun 30, 2024',
#   9900000.0,
#   'Villarreal CF'),
#  ('Manu Morlanes',
#   'Central Midfield',
#   23,
#   'Jun 30, 2026',
#   5500000.0,
#   'Villarreal CF'),
#  ('Álex Baena',
#   'Left Winger',
#   21,
#   'Jun 30, 2025',
#   11000000.0,
#   'Villarreal CF'),
#  ('Yéremy Pino',
#   'Right Winger',
#   20,
#   'Jun 30, 2027',
#   44000000.0,
#   'Villarreal CF'),
#  ('Samuel Chukwueze',
#   'Right Winger',
#   23,
#   'Jun 30, 2024',
#   22000000.0,
#   'Villarreal CF'),
#  ('Nicolas Jackson',
#   'Right Winger',
#   21,
#   'Jun 30, 2023',
#   11000000.0,
#   'Villarreal CF'),
#  ('Arnaut Danjuma',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2026',
#   55000000.0,
#   'Villarreal CF'),
#  ('Gerard Moreno',
#   'Centre-Forward',
#   30,
#   'Jun 30, 2027',
#   44000000.0,
#   'Villarreal CF'),
#  ('José Luis Morales',
#   'Centre-Forward',
#   35,
#   'Jun 30, 2024',
#   4400000.0,
#   'Villarreal CF'),
#  ('Bono', 'Goalkeeper', 31, 'Jun 30, 2025', 19800000.0, 'Sevilla FC'),
#  ('Marko Dmitrović',
#   'Goalkeeper',
#   30,
#   'Jun 30, 2025',
#   5500000.0,
#   'Sevilla FC'),
#  ('Marcão', 'Centre-Back', 26, 'Jun 30, 2027', 15400000.0, 'Sevilla FC'),
#  ('Tanguy Nianzou',
#   'Centre-Back',
#   20,
#   'Jun 30, 2027',
#   9900000.0,
#   'Sevilla FC'),
#  ('Karim Rekik', 'Centre-Back', 27, 'Jun 30, 2025', 5500000.0, 'Sevilla FC'),
#  ('Alex Telles', 'Left-Back', 29, 'Jun 30, 2023', 19800000.0, 'Sevilla FC'),
#  ('Marcos Acuña', 'Left-Back', 31, 'Jun 30, 2025', 19800000.0, 'Sevilla FC'),
#  ('Gonzalo Montiel',
#   'Right-Back',
#   25,
#   'Jun 30, 2026',
#   15400000.0,
#   'Sevilla FC'),
#  ('José Ángel Carmona',
#   'Right-Back',
#   20,
#   'Jun 30, 2025',
#   5500000.0,
#   'Sevilla FC'),
#  ('Jesús Navas', 'Right-Back', 36, 'Jun 30, 2024', 3300000.0, 'Sevilla FC'),
#  ('Nemanja Gudelj',
#   'Defensive Midfield',
#   30,
#   'Jun 30, 2023',
#   4400000.0,
#   'Sevilla FC'),
#  ('Fernando',
#   'Defensive Midfield',
#   35,
#   'Jun 30, 2024',
#   4400000.0,
#   'Sevilla FC'),
#  ('Joan Jordán',
#   'Central Midfield',
#   28,
#   'Jun 30, 2027',
#   19800000.0,
#   'Sevilla FC'),
#  ('Óliver Torres',
#   'Central Midfield',
#   27,
#   'Jun 30, 2024',
#   8800000.0,
#   'Sevilla FC'),
#  ('Ivan Rakitic',
#   'Central Midfield',
#   34,
#   'Jun 30, 2024',
#   7700000.0,
#   'Sevilla FC'),
#  ('Thomas Delaney',
#   'Central Midfield',
#   31,
#   'Jun 30, 2025',
#   7700000.0,
#   'Sevilla FC'),
#  ('Isco', 'Attacking Midfield', 30, 'Jun 30, 2024', 8250000.0, 'Sevilla FC'),
#  ('Papu Gómez', 'Left Winger', 34, 'Jun 30, 2024', 6600000.0, 'Sevilla FC'),
#  ('Tecatito', 'Right Winger', 29, 'Jun 30, 2025', 19800000.0, 'Sevilla FC'),
#  ('Erik Lamela', 'Right Winger', 30, 'Jun 30, 2024', 17600000.0, 'Sevilla FC'),
#  ('Suso', 'Right Winger', 28, 'Jun 30, 2025', 11000000.0, 'Sevilla FC'),
#  ('Adnan Januzaj',
#   'Right Winger',
#   27,
#   'Jun 30, 2026',
#   9900000.0,
#   'Sevilla FC'),
#  ('Youssef En-Nesyri',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2025',
#   22000000.0,
#   'Sevilla FC'),
#  ('Kasper Dolberg',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2023',
#   18700000.0,
#   'Sevilla FC'),
#  ('Rafa Mir', 'Centre-Forward', 25, 'Jun 30, 2027', 17600000.0, 'Sevilla FC'),
#  ('Rui Silva',
#   'Goalkeeper',
#   28,
#   'Jun 30, 2026',
#   16500000.0,
#   'Real Betis Balompié'),
#  ('Dani Martín',
#   'Goalkeeper',
#   24,
#   'Jun 30, 2024',
#   2200000.0,
#   'Real Betis Balompié'),
#  ('Claudio Bravo',
#   'Goalkeeper',
#   39,
#   'Jun 30, 2023',
#   1100000.0,
#   'Real Betis Balompié'),
#  ('Luiz Felipe',
#   'Centre-Back',
#   25,
#   'Jun 30, 2027',
#   19800000.0,
#   'Real Betis Balompié'),
#  ('Edgar González',
#   'Centre-Back',
#   25,
#   'Jun 30, 2025',
#   8800000.0,
#   'Real Betis Balompié'),
#  ('Germán Pezzella',
#   'Centre-Back',
#   31,
#   'Jun 30, 2025',
#   5500000.0,
#   'Real Betis Balompié'),
#  ('Víctor Ruiz',
#   'Centre-Back',
#   33,
#   'Jun 30, 2023',
#   1650000.0,
#   'Real Betis Balompié'),
#  ('Álex Moreno',
#   'Left-Back',
#   29,
#   'Jun 30, 2025',
#   19800000.0,
#   'Real Betis Balompié'),
#  ('Juan Miranda',
#   'Left-Back',
#   22,
#   'Jun 30, 2024',
#   5500000.0,
#   'Real Betis Balompié'),
#  ('Youssouf Sabaly',
#   'Right-Back',
#   29,
#   'Jun 30, 2026',
#   3300000.0,
#   'Real Betis Balompié'),
#  ('Aitor Ruibal',
#   'Right-Back',
#   26,
#   'Jun 30, 2025',
#   3300000.0,
#   'Real Betis Balompié'),
#  ('Martín Montoya',
#   'Right-Back',
#   31,
#   'Jun 30, 2024',
#   1650000.0,
#   'Real Betis Balompié'),
#  ('Guido Rodríguez',
#   'Defensive Midfield',
#   28,
#   'Jun 30, 2024',
#   27500000.0,
#   'Real Betis Balompié'),
#  ('William Carvalho',
#   'Defensive Midfield',
#   30,
#   'Jun 30, 2026',
#   17600000.0,
#   'Real Betis Balompié'),
#  ('Paul Akouokou',
#   'Defensive Midfield',
#   24,
#   'Jun 30, 2024',
#   4400000.0,
#   'Real Betis Balompié'),
#  ('Andrés Guardado',
#   'Central Midfield',
#   36,
#   'Jun 30, 2023',
#   1650000.0,
#   'Real Betis Balompié'),
#  ('Víctor Camarasa',
#   'Central Midfield',
#   28,
#   'Jun 30, 2023',
#   1100000.0,
#   'Real Betis Balompié'),
#  ('Nabil Fekir',
#   'Attacking Midfield',
#   29,
#   'Jun 30, 2026',
#   44000000.0,
#   'Real Betis Balompié'),
#  ('Sergio Canales',
#   'Attacking Midfield',
#   31,
#   'Jun 30, 2026',
#   22000000.0,
#   'Real Betis Balompié'),
#  ('Rodri Sánchez',
#   'Attacking Midfield',
#   22,
#   'Jun 30, 2026',
#   7700000.0,
#   'Real Betis Balompié'),
#  ('Juanmi',
#   'Left Winger',
#   29,
#   'Jun 30, 2024',
#   16500000.0,
#   'Real Betis Balompié'),
#  ('Luiz Henrique',
#   'Right Winger',
#   21,
#   'Jun 30, 2028',
#   13200000.0,
#   'Real Betis Balompié'),
#  ('Joaquín',
#   'Right Winger',
#   41,
#   'Jun 30, 2023',
#   1650000.0,
#   'Real Betis Balompié'),
#  ('Borja Iglesias',
#   'Centre-Forward',
#   29,
#   'Jun 30, 2026',
#   22000000.0,
#   'Real Betis Balompié'),
#  ('Willian José',
#   'Centre-Forward',
#   30,
#   'Jun 30, 2026',
#   13200000.0,
#   'Real Betis Balompié'),
#  ('Loren Morón',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2024',
#   4400000.0,
#   'Real Betis Balompié'),
#  ('Giorgi Mamardashvili',
#   'Goalkeeper',
#   22,
#   'Jun 30, 2027',
#   22000000.0,
#   'Valencia CF'),
#  ('Jaume Doménech',
#   'Goalkeeper',
#   31,
#   'Jun 30, 2023',
#   2200000.0,
#   'Valencia CF'),
#  ('Iago Herrerín', 'Goalkeeper', 34, 'Jun 30, 2023', 550000.0, 'Valencia CF'),
#  ('Cristian Rivero',
#   'Goalkeeper',
#   24,
#   'Jun 30, 2024',
#   220000.0,
#   'Valencia CF'),
#  ('Mouctar Diakhaby',
#   'Centre-Back',
#   25,
#   'Jun 30, 2023',
#   8800000.0,
#   'Valencia CF'),
#  ('Gabriel Paulista',
#   'Centre-Back',
#   31,
#   'Jun 30, 2024',
#   5500000.0,
#   'Valencia CF'),
#  ('Cenk Özkacar', 'Centre-Back', 22, 'Jun 30, 2023', 2200000.0, 'Valencia CF'),
#  ('Eray Cömert', 'Centre-Back', 24, 'Jun 30, 2026', 2200000.0, 'Valencia CF'),
#  ('Cristhian Mosquera',
#   'Centre-Back',
#   18,
#   'Jun 30, 2025',
#   1100000.0,
#   'Valencia CF'),
#  ('José Gayà', 'Left-Back', 27, 'Jun 30, 2027', 38500000.0, 'Valencia CF'),
#  ('Jesús Vázquez', 'Left-Back', 19, 'Jun 30, 2025', 5500000.0, 'Valencia CF'),
#  ('Toni Lato', 'Left-Back', 24, 'Jun 30, 2023', 2750000.0, 'Valencia CF'),
#  ('Thierry Correia',
#   'Right-Back',
#   23,
#   'Jun 30, 2026',
#   13200000.0,
#   'Valencia CF'),
#  ('Dimitri Foulquier',
#   'Right-Back',
#   29,
#   'Jun 30, 2025',
#   3300000.0,
#   'Valencia CF'),
#  ('Hugo Guillamón',
#   'Defensive Midfield',
#   22,
#   'Jun 30, 2026',
#   27500000.0,
#   'Valencia CF'),
#  ('Yunus Musah',
#   'Central Midfield',
#   19,
#   'Jun 30, 2026',
#   27500000.0,
#   'Valencia CF'),
#  ('Nico González',
#   'Central Midfield',
#   20,
#   'Jun 30, 2023',
#   22000000.0,
#   'Valencia CF'),
#  ('Ilaix Moriba',
#   'Central Midfield',
#   19,
#   'Jun 30, 2023',
#   9900000.0,
#   'Valencia CF'),
#  ('André Almeida',
#   'Central Midfield',
#   22,
#   'Jun 30, 2028',
#   8800000.0,
#   'Valencia CF'),
#  ('Justin Kluivert',
#   'Left Winger',
#   23,
#   'Jun 30, 2023',
#   16500000.0,
#   'Valencia CF'),
#  ('Samuel Lino', 'Left Winger', 22, 'Jun 30, 2023', 13200000.0, 'Valencia CF'),
#  ('Samu Castillejo',
#   'Right Winger',
#   27,
#   'Jun 30, 2025',
#   6600000.0,
#   'Valencia CF'),
#  ('Hugo Duro',
#   'Centre-Forward',
#   22,
#   'Jun 30, 2026',
#   11000000.0,
#   'Valencia CF'),
#  ('Marcos André',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2026',
#   5500000.0,
#   'Valencia CF'),
#  ('Edinson Cavani',
#   'Centre-Forward',
#   35,
#   'Jun 30, 2024',
#   4400000.0,
#   'Valencia CF'),
#  ('Unai Simón',
#   'Goalkeeper',
#   25,
#   'Jun 30, 2025',
#   27500000.0,
#   'Athletic Bilbao'),
#  ('Julen Agirrezabala',
#   'Goalkeeper',
#   21,
#   'Jun 30, 2025',
#   5500000.0,
#   'Athletic Bilbao'),
#  ('Iñigo Martínez',
#   'Centre-Back',
#   31,
#   'Jun 30, 2023',
#   22000000.0,
#   'Athletic Bilbao'),
#  ('Dani Vivian',
#   'Centre-Back',
#   23,
#   'Jun 30, 2026',
#   16500000.0,
#   'Athletic Bilbao'),
#  ('Yeray Álvarez',
#   'Centre-Back',
#   27,
#   'Jun 30, 2026',
#   14300000.0,
#   'Athletic Bilbao'),
#  ('Aitor Paredes',
#   'Centre-Back',
#   22,
#   'Jun 30, 2025',
#   440000.0,
#   'Athletic Bilbao'),
#  ('Yuri Berchiche',
#   'Left-Back',
#   32,
#   'Jun 30, 2024',
#   3300000.0,
#   'Athletic Bilbao'),
#  ('Mikel Balenziaga',
#   'Left-Back',
#   34,
#   'Jun 30, 2023',
#   1320000.0,
#   'Athletic Bilbao'),
#  ('Iñigo Lekue',
#   'Right-Back',
#   29,
#   'Jun 30, 2023',
#   3300000.0,
#   'Athletic Bilbao'),
#  ('Ander Capa',
#   'Right-Back',
#   30,
#   'Jun 30, 2024',
#   2750000.0,
#   'Athletic Bilbao'),
#  ('Óscar de Marcos',
#   'Right-Back',
#   33,
#   'Jun 30, 2023',
#   1980000.0,
#   'Athletic Bilbao'),
#  ('Mikel Vesga',
#   'Defensive Midfield',
#   29,
#   'Jun 30, 2024',
#   3300000.0,
#   'Athletic Bilbao'),
#  ('Unai Vencedor',
#   'Central Midfield',
#   21,
#   'Jun 30, 2027',
#   22000000.0,
#   'Athletic Bilbao'),
#  ('Ander Herrera',
#   'Central Midfield',
#   33,
#   'Jun 30, 2023',
#   8800000.0,
#   'Athletic Bilbao'),
#  ('Oier Zarraga',
#   'Central Midfield',
#   23,
#   'Jun 30, 2023',
#   3850000.0,
#   'Athletic Bilbao'),
#  ('Dani García',
#   'Central Midfield',
#   32,
#   'Jun 30, 2024',
#   3300000.0,
#   'Athletic Bilbao'),
#  ('Oihan Sancet',
#   'Attacking Midfield',
#   22,
#   'Jun 30, 2024',
#   22000000.0,
#   'Athletic Bilbao'),
#  ('Iker Muniain',
#   'Attacking Midfield',
#   29,
#   'Jun 30, 2024',
#   17600000.0,
#   'Athletic Bilbao'),
#  ('Jon Morcillo',
#   'Left Winger',
#   24,
#   'Jun 30, 2024',
#   4400000.0,
#   'Athletic Bilbao'),
#  ('Nico Williams',
#   'Right Winger',
#   20,
#   'Jun 30, 2024',
#   24200000.0,
#   'Athletic Bilbao'),
#  ('Álex Berenguer',
#   'Right Winger',
#   27,
#   'Jun 30, 2024',
#   16500000.0,
#   'Athletic Bilbao'),
#  ('Iñaki Williams',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2028',
#   27500000.0,
#   'Athletic Bilbao'),
#  ('Asier Villalibre',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2023',
#   3300000.0,
#   'Athletic Bilbao'),
#  ('Raúl García',
#   'Centre-Forward',
#   36,
#   'Jun 30, 2023',
#   2750000.0,
#   'Athletic Bilbao'),
#  ('Gorka Guruzeta',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2024',
#   2200000.0,
#   'Athletic Bilbao'),
#  ('David Soria', 'Goalkeeper', 29, 'Jun 30, 2023', 8800000.0, 'Getafe CF'),
#  ('Kiko Casilla', 'Goalkeeper', 36, 'Jun 30, 2023', 770000.0, 'Getafe CF'),
#  ('Diego Conde', 'Goalkeeper', 24, 'Jun 30, 2024', 330000.0, 'Getafe CF'),
#  ('Djené', 'Centre-Back', 30, '-', 8800000.0, 'Getafe CF'),
#  ('Domingos Duarte',
#   'Centre-Back',
#   27,
#   'Jun 30, 2026',
#   8800000.0,
#   'Getafe CF'),
#  ('Omar Alderete', 'Centre-Back', 25, 'Jun 30, 2023', 7700000.0, 'Getafe CF'),
#  ('Gastón Álvarez', 'Centre-Back', 22, 'Jun 30, 2023', 4400000.0, 'Getafe CF'),
#  ('Stefan Mitrović',
#   'Centre-Back',
#   32,
#   'Jun 30, 2024',
#   1980000.0,
#   'Getafe CF'),
#  ('Jordan Amavi', 'Left-Back', 28, 'Jun 30, 2023', 5500000.0, 'Getafe CF'),
#  ('Fabrizio Angileri',
#   'Left-Back',
#   28,
#   'Jun 30, 2026',
#   3300000.0,
#   'Getafe CF'),
#  ('Juan Iglesias', 'Right-Back', 24, 'Jun 30, 2026', 2750000.0, 'Getafe CF'),
#  ('Damián Suárez', 'Right-Back', 34, 'Jun 30, 2023', 1650000.0, 'Getafe CF'),
#  ('Nemanja Maksimović',
#   'Defensive Midfield',
#   27,
#   'Jun 30, 2024',
#   13200000.0,
#   'Getafe CF'),
#  ('Mauro Arambarri',
#   'Central Midfield',
#   27,
#   'Jun 30, 2023',
#   16500000.0,
#   'Getafe CF'),
#  ('Carles Aleñá',
#   'Central Midfield',
#   24,
#   'Jun 30, 2026',
#   9900000.0,
#   'Getafe CF'),
#  ('Luis Milla',
#   'Central Midfield',
#   28,
#   'Jun 30, 2027',
#   4400000.0,
#   'Getafe CF'),
#  ('Jaime Seoane',
#   'Central Midfield',
#   25,
#   'Jun 30, 2025',
#   4400000.0,
#   'Getafe CF'),
#  ('Ángel Algobia',
#   'Central Midfield',
#   23,
#   'Jun 30, 2023',
#   550000.0,
#   'Getafe CF'),
#  ('Portu', 'Right Winger', 30, 'Jun 30, 2023', 6600000.0, 'Getafe CF'),
#  ('Enes Ünal', 'Centre-Forward', 25, 'Jun 30, 2025', 27500000.0, 'Getafe CF'),
#  ('Borja Mayoral',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2027',
#   9900000.0,
#   'Getafe CF'),
#  ('Munir El Haddadi',
#   'Centre-Forward',
#   27,
#   'Jun 30, 2023',
#   6600000.0,
#   'Getafe CF'),
#  ('Jaime Mata', 'Centre-Forward', 34, 'Jun 30, 2024', 3300000.0, 'Getafe CF'),
#  ('Juanmi Latasa',
#   'Centre-Forward',
#   21,
#   'Jun 30, 2023',
#   1100000.0,
#   'Getafe CF'),
#  ('Agustín Marchesín',
#   'Goalkeeper',
#   34,
#   'Jun 30, 2025',
#   4400000.0,
#   'Celta de Vigo'),
#  ('Iván Villar', 'Goalkeeper', 25, 'Jun 30, 2023', 1320000.0, 'Celta de Vigo'),
#  ('Unai Núñez', 'Centre-Back', 25, 'Jun 30, 2023', 9900000.0, 'Celta de Vigo'),
#  ('Joseph Aidoo',
#   'Centre-Back',
#   27,
#   'Jun 30, 2026',
#   7700000.0,
#   'Celta de Vigo'),
#  ('Óscar Mingueza',
#   'Centre-Back',
#   23,
#   'Jun 30, 2026',
#   5500000.0,
#   'Celta de Vigo'),
#  ('Carlos Domínguez',
#   'Centre-Back',
#   21,
#   'Jun 30, 2026',
#   1100000.0,
#   'Celta de Vigo'),
#  ('Javi Galán', 'Left-Back', 27, 'Jun 30, 2026', 13200000.0, 'Celta de Vigo'),
#  ('Hugo Mallo', 'Right-Back', 31, 'Jun 30, 2023', 4400000.0, 'Celta de Vigo'),
#  ('Kevin Vázquez',
#   'Right-Back',
#   29,
#   'Jun 30, 2023',
#   2200000.0,
#   'Celta de Vigo'),
#  ('Renato Tapia',
#   'Defensive Midfield',
#   27,
#   'Jun 30, 2024',
#   11000000.0,
#   'Celta de Vigo'),
#  ('Fran Beltrán',
#   'Central Midfield',
#   23,
#   'Jun 30, 2026',
#   16500000.0,
#   'Celta de Vigo'),
#  ('Williot Swedberg',
#   'Central Midfield',
#   18,
#   'Jun 30, 2027',
#   5500000.0,
#   'Celta de Vigo'),
#  ('Luca de la Torre',
#   'Central Midfield',
#   24,
#   'Jun 30, 2026',
#   2200000.0,
#   'Celta de Vigo'),
#  ('Óscar Rodríguez',
#   'Attacking Midfield',
#   24,
#   'Jun 30, 2023',
#   9900000.0,
#   'Celta de Vigo'),
#  ('Denis Suárez',
#   'Attacking Midfield',
#   28,
#   'Jun 30, 2024',
#   5500000.0,
#   'Celta de Vigo'),
#  ('Gabri Veiga',
#   'Attacking Midfield',
#   20,
#   'Jun 30, 2026',
#   3300000.0,
#   'Celta de Vigo'),
#  ('Franco Cervi',
#   'Left Winger',
#   28,
#   'Jun 30, 2024',
#   5500000.0,
#   'Celta de Vigo'),
#  ('Carles Pérez',
#   'Right Winger',
#   24,
#   'Jun 30, 2023',
#   6600000.0,
#   'Celta de Vigo'),
#  ('Augusto Solari',
#   'Right Winger',
#   30,
#   'Jun 30, 2023',
#   2750000.0,
#   'Celta de Vigo'),
#  ('Jörgen Strand Larsen',
#   'Centre-Forward',
#   22,
#   'Jun 30, 2028',
#   12100000.0,
#   'Celta de Vigo'),
#  ('Iago Aspas',
#   'Centre-Forward',
#   35,
#   'Jun 30, 2025',
#   7700000.0,
#   'Celta de Vigo'),
#  ('Gonçalo Paciência',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2025',
#   3300000.0,
#   'Celta de Vigo'),
#  ('Sergio Herrera', 'Goalkeeper', 29, '-', 8800000.0, 'CA Osasuna'),
#  ('Aitor Fernández',
#   'Goalkeeper',
#   31,
#   'Jun 30, 2025',
#   2750000.0,
#   'CA Osasuna'),
#  ('Juan Pérez', 'Goalkeeper', 26, 'Jun 30, 2024', 660000.0, 'CA Osasuna'),
#  ('David García', 'Centre-Back', 28, 'Jun 30, 2026', 22000000.0, 'CA Osasuna'),
#  ('Unai García', 'Centre-Back', 30, 'Jun 30, 2023', 1650000.0, 'CA Osasuna'),
#  ('Aridane Hernández',
#   'Centre-Back',
#   33,
#   'Jun 30, 2023',
#   1650000.0,
#   'CA Osasuna'),
#  ('Manu Sánchez', 'Left-Back', 22, 'Jun 30, 2023', 11000000.0, 'CA Osasuna'),
#  ('Juan Cruz', 'Left-Back', 30, 'Jun 30, 2024', 2200000.0, 'CA Osasuna'),
#  ('Nacho Vidal', 'Right-Back', 27, 'Jun 30, 2025', 5500000.0, 'CA Osasuna'),
#  ('Rubén Peña', 'Right-Back', 31, 'Jun 30, 2025', 2750000.0, 'CA Osasuna'),
#  ('Lucas Torró',
#   'Defensive Midfield',
#   28,
#   'Jun 30, 2027',
#   5500000.0,
#   'CA Osasuna'),
#  ('Jon Moncayola',
#   'Central Midfield',
#   24,
#   'Jun 30, 2031',
#   13200000.0,
#   'CA Osasuna'),
#  ('Darko Brasanac',
#   'Central Midfield',
#   30,
#   'Jun 30, 2023',
#   2200000.0,
#   'CA Osasuna'),
#  ('Pablo Ibáñez',
#   'Central Midfield',
#   24,
#   'Jun 30, 2024',
#   440000.0,
#   'CA Osasuna'),
#  ('Roberto Torres',
#   'Attacking Midfield',
#   33,
#   'Jun 30, 2023',
#   3300000.0,
#   'CA Osasuna'),
#  ('Aimar Oroz',
#   'Attacking Midfield',
#   20,
#   'Jun 30, 2026',
#   3300000.0,
#   'CA Osasuna'),
#  ('Ez Abde', 'Left Winger', 20, 'Jun 30, 2023', 8800000.0, 'CA Osasuna'),
#  ('Rubén García', 'Left Winger', 29, 'Jun 30, 2024', 8800000.0, 'CA Osasuna'),
#  ('Moi Gómez', 'Left Winger', 28, 'Jun 30, 2027', 8800000.0, 'CA Osasuna'),
#  ('Kike Saverio', 'Left Winger', 23, 'Jun 30, 2023', 220000.0, 'CA Osasuna'),
#  ('Kike Barja', 'Right Winger', 25, 'Jun 30, 2026', 3300000.0, 'CA Osasuna'),
#  ('Chimy Ávila',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2026',
#   11000000.0,
#   'CA Osasuna'),
#  ('Ante Budimir',
#   'Centre-Forward',
#   31,
#   'Jun 30, 2025',
#   6600000.0,
#   'CA Osasuna'),
#  ('Kike García',
#   'Centre-Forward',
#   32,
#   'Jun 30, 2024',
#   1980000.0,
#   'CA Osasuna'),
#  ('Benjamin Lecomte',
#   'Goalkeeper',
#   31,
#   'Jun 30, 2023',
#   5500000.0,
#   'RCD Espanyol Barcelona'),
#  ('Álvaro Fernández',
#   'Goalkeeper',
#   24,
#   'Jun 30, 2023',
#   4400000.0,
#   'RCD Espanyol Barcelona'),
#  ('Joan García',
#   'Goalkeeper',
#   21,
#   'Jun 30, 2025',
#   440000.0,
#   'RCD Espanyol Barcelona'),
#  ('Leandro Cabrera',
#   'Centre-Back',
#   31,
#   'Jun 30, 2024',
#   4400000.0,
#   'RCD Espanyol Barcelona'),
#  ('Sergi Gómez',
#   'Centre-Back',
#   30,
#   'Jun 30, 2024',
#   3300000.0,
#   'RCD Espanyol Barcelona'),
#  ('Fernando Calero',
#   'Centre-Back',
#   27,
#   'Jun 30, 2024',
#   1980000.0,
#   'RCD Espanyol Barcelona'),
#  ('Adrià Pedrosa',
#   'Left-Back',
#   24,
#   'Jun 30, 2023',
#   7700000.0,
#   'RCD Espanyol Barcelona'),
#  ('Brian Oliván',
#   'Left-Back',
#   28,
#   'Jun 30, 2025',
#   2750000.0,
#   'RCD Espanyol Barcelona'),
#  ('Óscar Gil',
#   'Right-Back',
#   24,
#   'Jun 30, 2024',
#   3300000.0,
#   'RCD Espanyol Barcelona'),
#  ('Aleix Vidal',
#   'Right-Back',
#   33,
#   'Jun 30, 2023',
#   2200000.0,
#   'RCD Espanyol Barcelona'),
#  ('Vinicius Souza',
#   'Defensive Midfield',
#   23,
#   'Jun 30, 2023',
#   4950000.0,
#   'RCD Espanyol Barcelona'),
#  ('Sergi Darder',
#   'Central Midfield',
#   28,
#   'Jun 30, 2026',
#   15400000.0,
#   'RCD Espanyol Barcelona'),
#  ('Keidi Bare',
#   'Central Midfield',
#   25,
#   'Jun 30, 2024',
#   4400000.0,
#   'RCD Espanyol Barcelona'),
#  ('Edu Expósito',
#   'Central Midfield',
#   26,
#   'Jun 30, 2027',
#   4400000.0,
#   'RCD Espanyol Barcelona'),
#  ('Pol Lozano',
#   'Central Midfield',
#   23,
#   'Jun 30, 2023',
#   1650000.0,
#   'RCD Espanyol Barcelona'),
#  ('Javi Puado',
#   'Left Winger',
#   24,
#   'Jun 30, 2025',
#   8800000.0,
#   'RCD Espanyol Barcelona'),
#  ('Nico Melamed',
#   'Left Winger',
#   21,
#   'Jun 30, 2024',
#   8250000.0,
#   'RCD Espanyol Barcelona'),
#  ('José Carlos Lazo',
#   'Left Winger',
#   26,
#   'Jun 30, 2027',
#   2750000.0,
#   'RCD Espanyol Barcelona'),
#  ('Martin Braithwaite',
#   'Centre-Forward',
#   31,
#   'Jun 30, 2025',
#   6600000.0,
#   'RCD Espanyol Barcelona'),
#  ('Joselu',
#   'Centre-Forward',
#   32,
#   'Jun 30, 2025',
#   5500000.0,
#   'RCD Espanyol Barcelona'),
#  ('Dani Gómez',
#   'Centre-Forward',
#   24,
#   'Jun 30, 2023',
#   2750000.0,
#   'RCD Espanyol Barcelona'),
#  ('Paulo Gazzaniga', 'Goalkeeper', 30, 'Jun 30, 2023', 2200000.0, 'Girona FC'),
#  ('Juan Carlos', 'Goalkeeper', 34, 'Jun 30, 2023', 330000.0, 'Girona FC'),
#  ('Toni Fuidias', 'Goalkeeper', 21, 'Jun 30, 2025', 330000.0, 'Girona FC'),
#  ('Santiago Bueno', 'Centre-Back', 23, 'Jun 30, 2024', 3300000.0, 'Girona FC'),
#  ('David López', 'Centre-Back', 33, 'Jun 30, 2023', 1980000.0, 'Girona FC'),
#  ('Bernardo Espinosa',
#   'Centre-Back',
#   33,
#   'Jun 30, 2023',
#   1650000.0,
#   'Girona FC'),
#  ('Juanpe', 'Centre-Back', 31, 'Jun 30, 2023', 1650000.0, 'Girona FC'),
#  ('Miguel Gutiérrez', 'Left-Back', 21, 'Jun 30, 2027', 8800000.0, 'Girona FC'),
#  ('Javi Hernández', 'Left-Back', 24, 'Jun 30, 2023', 2750000.0, 'Girona FC'),
#  ('Arnau Martínez', 'Right-Back', 19, 'Jun 30, 2025', 6600000.0, 'Girona FC'),
#  ('Yan Couto', 'Right-Back', 20, 'Jun 30, 2023', 5500000.0, 'Girona FC'),
#  ('Oriol Romeu',
#   'Defensive Midfield',
#   31,
#   'Jun 30, 2025',
#   5500000.0,
#   'Girona FC'),
#  ('Ramón Terrats',
#   'Defensive Midfield',
#   22,
#   'Jun 30, 2024',
#   1100000.0,
#   'Girona FC'),
#  ('Ibrahima Kébé',
#   'Defensive Midfield',
#   22,
#   'Jun 30, 2024',
#   660000.0,
#   'Girona FC'),
#  ('Yangel Herrera',
#   'Central Midfield',
#   24,
#   'Jun 30, 2023',
#   15400000.0,
#   'Girona FC'),
#  ('Aleix García',
#   'Central Midfield',
#   25,
#   'Jun 30, 2023',
#   4400000.0,
#   'Girona FC'),
#  ('Reinier', 'Attacking Midfield', 20, 'Jun 30, 2023', 8800000.0, 'Girona FC'),
#  ('Borja García',
#   'Attacking Midfield',
#   32,
#   'Jun 30, 2023',
#   1650000.0,
#   'Girona FC'),
#  ('Iván Martín',
#   'Attacking Midfield',
#   23,
#   'Jun 30, 2023',
#   880000.0,
#   'Girona FC'),
#  ('Manu Vallejo', 'Left Winger', 25, 'Jun 30, 2025', 3300000.0, 'Girona FC'),
#  ('Toni Villa', 'Left Winger', 27, 'Jun 30, 2025', 2750000.0, 'Girona FC'),
#  ('Samu Saiz', 'Left Winger', 31, 'Jun 30, 2023', 1100000.0, 'Girona FC'),
#  ('Rodrigo Riquelme',
#   'Right Winger',
#   22,
#   'Jun 30, 2023',
#   4400000.0,
#   'Girona FC'),
#  ('Valery Fernández',
#   'Right Winger',
#   22,
#   'Jun 30, 2023',
#   880000.0,
#   'Girona FC'),
#  ('Taty Castellanos',
#   'Centre-Forward',
#   24,
#   'Jun 30, 2023',
#   13200000.0,
#   'Girona FC'),
#  ('Cristhian Stuani',
#   'Centre-Forward',
#   36,
#   'Jun 30, 2026',
#   1650000.0,
#   'Girona FC'),
#  ('Fernando Pacheco',
#   'Goalkeeper',
#   30,
#   'Jun 30, 2026',
#   3300000.0,
#   'UD Almería'),
#  ('Fernando Martínez',
#   'Goalkeeper',
#   32,
#   'Jun 30, 2023',
#   1100000.0,
#   'UD Almería'),
#  ('Diego Fuoli', 'Goalkeeper', 25, 'Jun 30, 2023', 220000.0, 'UD Almería'),
#  ('Kaiky', 'Centre-Back', 18, 'Jun 30, 2028', 8800000.0, 'UD Almería'),
#  ('Rodrigo Ely', 'Centre-Back', 28, 'Jun 30, 2024', 3300000.0, 'UD Almería'),
#  ('Srdjan Babic', 'Centre-Back', 26, 'Jun 30, 2026', 3300000.0, 'UD Almería'),
#  ('Chumi', 'Centre-Back', 23, 'Jun 30, 2025', 2200000.0, 'UD Almería'),
#  ('Iván Martos', 'Centre-Back', 25, 'Jun 30, 2024', 440000.0, 'UD Almería'),
#  ('Sergio Akieme', 'Left-Back', 24, 'Jun 30, 2026', 5500000.0, 'UD Almería'),
#  ('Álex Centelles', 'Left-Back', 23, 'Jun 30, 2026', 1650000.0, 'UD Almería'),
#  ('Alejandro Pozo', 'Right-Back', 23, 'Jun 30, 2027', 4400000.0, 'UD Almería'),
#  ('Houboulang Mendes',
#   'Right-Back',
#   24,
#   'Jun 30, 2026',
#   3300000.0,
#   'UD Almería'),
#  ('Juanjo Nieto', 'Right-Back', 28, 'Jun 30, 2023', 770000.0, 'UD Almería'),
#  ('Samú Costa',
#   'Defensive Midfield',
#   21,
#   'Jun 30, 2026',
#   6600000.0,
#   'UD Almería'),
#  ('Iñigo Eguaras',
#   'Defensive Midfield',
#   30,
#   'Jun 30, 2024',
#   1100000.0,
#   'UD Almería'),
#  ('Gonzalo Melero',
#   'Central Midfield',
#   28,
#   'Jun 30, 2026',
#   4400000.0,
#   'UD Almería'),
#  ('Lucas Robertone',
#   'Central Midfield',
#   25,
#   'Jun 30, 2025',
#   4400000.0,
#   'UD Almería'),
#  ('Arnau Puigmal',
#   'Central Midfield',
#   21,
#   'Jun 30, 2026',
#   1650000.0,
#   'UD Almería'),
#  ('Gui Guedes',
#   'Central Midfield',
#   20,
#   'Jun 30, 2028',
#   1650000.0,
#   'UD Almería'),
#  ('César de la Hoz',
#   'Central Midfield',
#   30,
#   'Jun 30, 2023',
#   1100000.0,
#   'UD Almería'),
#  ('Largie Ramazani',
#   'Left Winger',
#   21,
#   'Jun 30, 2025',
#   11000000.0,
#   'UD Almería'),
#  ('Lázaro', 'Left Winger', 20, 'Jun 30, 2028', 7700000.0, 'UD Almería'),
#  ('Adrián Embarba',
#   'Right Winger',
#   30,
#   'Jun 30, 2026',
#   4400000.0,
#   'UD Almería'),
#  ('Francisco Portillo',
#   'Right Winger',
#   32,
#   'Jun 30, 2023',
#   2200000.0,
#   'UD Almería'),
#  ('Léo Baptistão',
#   'Second Striker',
#   30,
#   'Jun 30, 2026',
#   1650000.0,
#   'UD Almería'),
#  ('El Bilal Touré',
#   'Centre-Forward',
#   21,
#   'Jun 30, 2028',
#   7150000.0,
#   'UD Almería'),
#  ('Marko Milovanovic',
#   'Centre-Forward',
#   19,
#   'Jun 30, 2028',
#   1320000.0,
#   'UD Almería'),
#  ('Dyego Sousa',
#   'Centre-Forward',
#   33,
#   'Jun 30, 2024',
#   1100000.0,
#   'UD Almería'),
#  ('Stole Dimitrievski',
#   'Goalkeeper',
#   28,
#   'Jun 30, 2024',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Miguel Ángel Morro',
#   'Goalkeeper',
#   22,
#   'Jun 30, 2023',
#   660000.0,
#   'Rayo Vallecano'),
#  ('Diego López', 'Goalkeeper', 40, 'Jun 30, 2023', 550000.0, 'Rayo Vallecano'),
#  ('Alejandro Catena',
#   'Centre-Back',
#   28,
#   'Jun 30, 2023',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Abdul Mumin',
#   'Centre-Back',
#   24,
#   'Jun 30, 2026',
#   3300000.0,
#   'Rayo Vallecano'),
#  ('Florian Lejeune',
#   'Centre-Back',
#   31,
#   'Jun 30, 2023',
#   2200000.0,
#   'Rayo Vallecano'),
#  ('Esteban Saveljich',
#   'Centre-Back',
#   31,
#   'Jun 30, 2023',
#   880000.0,
#   'Rayo Vallecano'),
#  ('Mario Suárez',
#   'Centre-Back',
#   35,
#   'Jun 30, 2023',
#   330000.0,
#   'Rayo Vallecano'),
#  ('Fran García', 'Left-Back', 23, 'Jun 30, 2025', 8250000.0, 'Rayo Vallecano'),
#  ('Pep Chavarría',
#   'Left-Back',
#   24,
#   'Jun 30, 2027',
#   880000.0,
#   'Rayo Vallecano'),
#  ('Iván Balliu',
#   'Right-Back',
#   30,
#   'Jun 30, 2025',
#   2200000.0,
#   'Rayo Vallecano'),
#  ('Mario Hernández',
#   'Right-Back',
#   23,
#   'Jun 30, 2023',
#   880000.0,
#   'Rayo Vallecano'),
#  ('Santi Comesaña',
#   'Central Midfield',
#   26,
#   'Jun 30, 2023',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Unai López',
#   'Central Midfield',
#   27,
#   'Jun 30, 2024',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Pathé Ciss',
#   'Central Midfield',
#   28,
#   'Jun 30, 2025',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Óscar Valentín',
#   'Central Midfield',
#   28,
#   'Jun 30, 2025',
#   3300000.0,
#   'Rayo Vallecano'),
#  ('Randy Nteka',
#   'Attacking Midfield',
#   24,
#   'Jun 30, 2026',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Óscar Trejo',
#   'Attacking Midfield',
#   34,
#   'Jun 30, 2024',
#   3300000.0,
#   'Rayo Vallecano'),
#  ('José Pozo',
#   'Attacking Midfield',
#   26,
#   'Jun 30, 2024',
#   1320000.0,
#   'Rayo Vallecano'),
#  ('Álvaro García',
#   'Left Winger',
#   30,
#   'Jun 30, 2026',
#   6600000.0,
#   'Rayo Vallecano'),
#  ('Bebé', 'Left Winger', 32, 'Jun 30, 2025', 880000.0, 'Rayo Vallecano'),
#  ('Isi Palazón',
#   'Right Winger',
#   27,
#   'Jun 30, 2025',
#   5500000.0,
#   'Rayo Vallecano'),
#  ('Salvi Sánchez',
#   'Right Winger',
#   31,
#   'Jun 30, 2024',
#   2200000.0,
#   'Rayo Vallecano'),
#  ('Raúl de Tomás',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2027',
#   13200000.0,
#   'Rayo Vallecano'),
#  ('Sergio Camello',
#   'Centre-Forward',
#   21,
#   'Jun 30, 2023',
#   4400000.0,
#   'Rayo Vallecano'),
#  ('Radamel Falcao',
#   'Centre-Forward',
#   36,
#   'Jun 30, 2023',
#   2200000.0,
#   'Rayo Vallecano'),
#  ('Andrés Martín',
#   'Centre-Forward',
#   23,
#   'Jun 30, 2024',
#   1320000.0,
#   'Rayo Vallecano'),
#  ('Édgar Badía', 'Goalkeeper', 30, 'Jun 30, 2025', 3300000.0, 'Elche CF'),
#  ('Axel Werner', 'Goalkeeper', 26, 'Jun 30, 2023', 880000.0, 'Elche CF'),
#  ('Enzo Roco', 'Centre-Back', 30, 'Jun 30, 2023', 2200000.0, 'Elche CF'),
#  ('Diego González', 'Centre-Back', 27, 'Jun 30, 2024', 2200000.0, 'Elche CF'),
#  ('Federico Fernández',
#   'Centre-Back',
#   33,
#   'Jun 30, 2023',
#   1650000.0,
#   'Elche CF'),
#  ('Pedro Bigas', 'Centre-Back', 32, 'Jun 30, 2023', 1100000.0, 'Elche CF'),
#  ('Gonzalo Verdú', 'Centre-Back', 34, 'Jun 30, 2023', 770000.0, 'Elche CF'),
#  ('John Nwankwo', 'Centre-Back', 22, 'Jun 30, 2025', 440000.0, 'Elche CF'),
#  ('Nicolás Fernández Mercau',
#   'Left-Back',
#   22,
#   'Jun 30, 2027',
#   2750000.0,
#   'Elche CF'),
#  ('Carlos Clerc', 'Left-Back', 30, 'Jun 30, 2024', 2200000.0, 'Elche CF'),
#  ('Pol Lirola', 'Right-Back', 25, 'Jun 30, 2023', 6600000.0, 'Elche CF'),
#  ('Helibelton Palacios',
#   'Right-Back',
#   29,
#   'Jun 30, 2023',
#   1320000.0,
#   'Elche CF'),
#  ('Omar Mascarell',
#   'Defensive Midfield',
#   29,
#   'Jun 30, 2025',
#   4400000.0,
#   'Elche CF'),
#  ('Gerard Gumbau',
#   'Defensive Midfield',
#   27,
#   'Jun 30, 2023',
#   3300000.0,
#   'Elche CF'),
#  ('Raúl Guti', 'Central Midfield', 25, 'Jun 30, 2025', 4400000.0, 'Elche CF'),
#  ('Domingos Quina',
#   'Central Midfield',
#   22,
#   'Jun 30, 2023',
#   2420000.0,
#   'Elche CF'),
#  ('Javier Pastore',
#   'Attacking Midfield',
#   33,
#   'Jun 30, 2023',
#   990000.0,
#   'Elche CF'),
#  ('Pere Milla', 'Left Winger', 30, 'Jun 30, 2025', 3300000.0, 'Elche CF'),
#  ('Tete Morente', 'Left Winger', 25, 'Jun 30, 2024', 3300000.0, 'Elche CF'),
#  ('Fidel', 'Left Winger', 33, 'Jun 30, 2024', 2200000.0, 'Elche CF'),
#  ('Álex Collado', 'Right Winger', 23, 'Jun 30, 2023', 5500000.0, 'Elche CF'),
#  ('Josan', 'Right Winger', 32, 'Jun 30, 2023', 1100000.0, 'Elche CF'),
#  ('Lucas Boyé', 'Centre-Forward', 26, 'Jun 30, 2024', 13200000.0, 'Elche CF'),
#  ('Ezequiel Ponce',
#   'Centre-Forward',
#   25,
#   'Jun 30, 2026',
#   5500000.0,
#   'Elche CF'),
#  ('Roger Martí', 'Centre-Forward', 31, 'Jun 30, 2026', 4400000.0, 'Elche CF'),
#  ('Predrag Rajković',
#   'Goalkeeper',
#   27,
#   'Jun 30, 2026',
#   9900000.0,
#   'RCD Mallorca'),
#  ('Dominik Greif',
#   'Goalkeeper',
#   25,
#   'Jun 30, 2026',
#   2200000.0,
#   'RCD Mallorca'),
#  ('Leo Román', 'Goalkeeper', 22, 'Jun 30, 2026', 330000.0, 'RCD Mallorca'),
#  ('Martin Valjent',
#   'Centre-Back',
#   26,
#   'Jun 30, 2025',
#   4400000.0,
#   'RCD Mallorca'),
#  ('Antonio Raíllo',
#   'Centre-Back',
#   31,
#   'Jun 30, 2024',
#   2200000.0,
#   'RCD Mallorca'),
#  ('Matija Nastasić',
#   'Centre-Back',
#   29,
#   'Jun 30, 2023',
#   1650000.0,
#   'RCD Mallorca'),
#  ('Franco Russo',
#   'Centre-Back',
#   28,
#   'Jun 30, 2024',
#   1320000.0,
#   'RCD Mallorca'),
#  ('José Copete', 'Centre-Back', 23, 'Jun 30, 2026', 1320000.0, 'RCD Mallorca'),
#  ('Braian Cufré', 'Left-Back', 25, 'Jun 30, 2024', 1320000.0, 'RCD Mallorca'),
#  ('Jaume Costa', 'Left-Back', 34, 'Jun 30, 2023', 1320000.0, 'RCD Mallorca'),
#  ('Pablo Maffeo', 'Right-Back', 25, 'Jun 30, 2026', 5500000.0, 'RCD Mallorca'),
#  ('Giovanni González',
#   'Right-Back',
#   28,
#   'Jun 30, 2024',
#   1650000.0,
#   'RCD Mallorca'),
#  ('Rodrigo Battaglia',
#   'Defensive Midfield',
#   31,
#   'Jun 30, 2024',
#   1980000.0,
#   'RCD Mallorca'),
#  ('Iddrisu Baba',
#   'Central Midfield',
#   26,
#   'Jun 30, 2024',
#   3850000.0,
#   'RCD Mallorca'),
#  ('Iñigo Ruiz de Galarreta',
#   'Central Midfield',
#   29,
#   'Jun 30, 2023',
#   1980000.0,
#   'RCD Mallorca'),
#  ('Antonio Sánchez',
#   'Central Midfield',
#   25,
#   'Jun 30, 2024',
#   1650000.0,
#   'RCD Mallorca'),
#  ('Clément Grenier',
#   'Central Midfield',
#   31,
#   'Jun 30, 2024',
#   1100000.0,
#   'RCD Mallorca'),
#  ('Kang-in Lee',
#   'Attacking Midfield',
#   21,
#   'Jun 30, 2025',
#   9900000.0,
#   'RCD Mallorca'),
#  ('Dani Rodríguez',
#   'Attacking Midfield',
#   34,
#   'Jun 30, 2024',
#   1320000.0,
#   'RCD Mallorca'),
#  ('Amath Ndiaye',
#   'Left Winger',
#   26,
#   'Jun 30, 2025',
#   2200000.0,
#   'RCD Mallorca'),
#  ('Lago Júnior', 'Left Winger', 31, 'Jun 30, 2023', 1320000.0, 'RCD Mallorca'),
#  ('Vedat Muriqi',
#   'Centre-Forward',
#   28,
#   'Jun 30, 2027',
#   9900000.0,
#   'RCD Mallorca'),
#  ('Tino Kadewere',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2023',
#   6600000.0,
#   'RCD Mallorca'),
#  ('Ángel Rodríguez',
#   'Centre-Forward',
#   35,
#   'Jun 30, 2023',
#   2200000.0,
#   'RCD Mallorca'),
#  ('Abdón Prats',
#   'Centre-Forward',
#   29,
#   'Jun 30, 2024',
#   1650000.0,
#   'RCD Mallorca'),
#  ('Sergio Asenjo',
#   'Goalkeeper',
#   33,
#   'Jun 30, 2024',
#   4400000.0,
#   'Real Valladolid CF'),
#  ('Jordi Masip',
#   'Goalkeeper',
#   33,
#   'Jun 30, 2024',
#   770000.0,
#   'Real Valladolid CF'),
#  ('Joaquín Fernández',
#   'Centre-Back',
#   26,
#   'Jun 30, 2023',
#   3080000.0,
#   'Real Valladolid CF'),
#  ('Zouhair Feddal',
#   'Centre-Back',
#   32,
#   'Jun 30, 2023',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Javi Sánchez',
#   'Centre-Back',
#   25,
#   'Jun 30, 2026',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Jawad El Yamiq',
#   'Centre-Back',
#   30,
#   'Jun 30, 2024',
#   1320000.0,
#   'Real Valladolid CF'),
#  ('Lucas Olaza',
#   'Left-Back',
#   28,
#   'Jun 30, 2025',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Sergio Escudero',
#   'Left-Back',
#   33,
#   'Jun 30, 2024',
#   1980000.0,
#   'Real Valladolid CF'),
#  ('Luis Pérez',
#   'Right-Back',
#   27,
#   'Jun 30, 2025',
#   1650000.0,
#   'Real Valladolid CF'),
#  ('Iván Fresneda',
#   'Right-Back',
#   18,
#   'Jun 30, 2025',
#   1100000.0,
#   'Real Valladolid CF'),
#  ('Lucas Rosa',
#   'Right-Back',
#   22,
#   'Jun 30, 2025',
#   165000.0,
#   'Real Valladolid CF'),
#  ('Mickaël Malsa',
#   'Defensive Midfield',
#   26,
#   'Jun 30, 2026',
#   3300000.0,
#   'Real Valladolid CF'),
#  ('Monchu',
#   'Central Midfield',
#   23,
#   'Jun 30, 2026',
#   3300000.0,
#   'Real Valladolid CF'),
#  ('Kike Pérez',
#   'Central Midfield',
#   25,
#   'Jun 30, 2025',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Álvaro Aguado',
#   'Central Midfield',
#   26,
#   'Jun 30, 2023',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Roque Mesa',
#   'Central Midfield',
#   33,
#   'Jun 30, 2023',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Anuar',
#   'Central Midfield',
#   27,
#   'Jun 30, 2023',
#   1100000.0,
#   'Real Valladolid CF'),
#  ('Kenedy',
#   'Left Winger',
#   26,
#   'Jun 30, 2027',
#   7700000.0,
#   'Real Valladolid CF'),
#  ('Gonzalo Plata',
#   'Right Winger',
#   22,
#   'Jun 30, 2027',
#   6600000.0,
#   'Real Valladolid CF'),
#  ('Óscar Plano',
#   'Right Winger',
#   31,
#   'Jun 30, 2023',
#   2750000.0,
#   'Real Valladolid CF'),
#  ('Iván Sánchez',
#   'Right Winger',
#   30,
#   'Jun 30, 2024',
#   880000.0,
#   'Real Valladolid CF'),
#  ('Shon Weissman',
#   'Centre-Forward',
#   26,
#   'Jun 30, 2024',
#   8800000.0,
#   'Real Valladolid CF'),
#  ('Sergi Guardiola',
#   'Centre-Forward',
#   31,
#   'Jun 30, 2023',
#   3300000.0,
#   'Real Valladolid CF'),
#  ('Juanjo Narváez',
#   'Centre-Forward',
#   27,
#   'Jun 30, 2025',
#   1650000.0,
#   'Real Valladolid CF'),
#  ('Sergio León',
#   'Centre-Forward',
#   33,
#   'Jun 30, 2024',
#   1320000.0,
#   'Real Valladolid CF'),
#  ('Jeremías Ledesma', 'Goalkeeper', 29, 'Jun 30, 2025', 6600000.0, 'Cádiz CF'),
#  ('David Gil', 'Goalkeeper', 28, 'Jun 30, 2025', 880000.0, 'Cádiz CF'),
#  ('Fali', 'Centre-Back', 29, 'Jun 30, 2024', 2750000.0, 'Cádiz CF'),
#  ('Víctor Chust', 'Centre-Back', 22, 'Jun 30, 2026', 2750000.0, 'Cádiz CF'),
#  ('Juan Cala', 'Centre-Back', 32, 'Jun 30, 2024', 990000.0, 'Cádiz CF'),
#  ('Luis Hernández', 'Centre-Back', 33, 'Jun 30, 2023', 880000.0, 'Cádiz CF'),
#  ('Momo Mbaye', 'Centre-Back', 24, 'Jun 30, 2024', 440000.0, 'Cádiz CF'),
#  ('Alfonso Espino', 'Left-Back', 30, 'Jun 30, 2023', 5500000.0, 'Cádiz CF'),
#  ('Santiago Arzamendia',
#   'Left-Back',
#   24,
#   'Jun 30, 2025',
#   1980000.0,
#   'Cádiz CF'),
#  ('Joseba Zaldua', 'Right-Back', 30, 'Jun 30, 2025', 4400000.0, 'Cádiz CF'),
#  ('Iza Carcelén', 'Right-Back', 29, 'Jun 30, 2023', 1650000.0, 'Cádiz CF'),
#  ('Antonio Blanco',
#   'Defensive Midfield',
#   22,
#   'Jun 30, 2023',
#   5500000.0,
#   'Cádiz CF'),
#  ('Tomás Alarcón',
#   'Defensive Midfield',
#   23,
#   'Jun 30, 2025',
#   3300000.0,
#   'Cádiz CF'),
#  ('Jon Ander Garrido',
#   'Defensive Midfield',
#   33,
#   'Jun 30, 2023',
#   440000.0,
#   'Cádiz CF'),
#  ('José Mari', 'Defensive Midfield', 34, 'Jun 30, 2024', 440000.0, 'Cádiz CF'),
#  ('Rubén Alcaraz',
#   'Central Midfield',
#   31,
#   'Jun 30, 2024',
#   2750000.0,
#   'Cádiz CF'),
#  ('Fede San Emeterio',
#   'Central Midfield',
#   25,
#   'Jun 30, 2026',
#   1650000.0,
#   'Cádiz CF'),
#  ('Álex Fernández',
#   'Attacking Midfield',
#   30,
#   'Jun 30, 2025',
#   5500000.0,
#   'Cádiz CF'),
#  ('Théo Bongonda', 'Left Winger', 26, 'Jun 30, 2026', 6600000.0, 'Cádiz CF'),
#  ('Awer Mabil', 'Left Winger', 27, 'Jun 30, 2026', 1980000.0, 'Cádiz CF'),
#  ('Brian Ocampo', 'Right Winger', 23, 'Jun 30, 2026', 2200000.0, 'Cádiz CF'),
#  ('Iván Alejo', 'Right Winger', 27, 'Jun 30, 2025', 1320000.0, 'Cádiz CF'),
#  ('Choco Lozano', 'Centre-Forward', 29, 'Jun 30, 2023', 3300000.0, 'Cádiz CF'),
#  ('Lucas Pérez', 'Centre-Forward', 34, 'Jun 30, 2023', 2750000.0, 'Cádiz CF'),
#  ('Rubén Sobrino',
#   'Centre-Forward',
#   30,
#   'Jun 30, 2024',
#   2200000.0,
#   'Cádiz CF'),
#  ('Álvaro Negredo',
#   'Centre-Forward',
#   37,
#   'Jun 30, 2023',
#   1650000.0,
#   'Cádiz CF'),
#  ('Álvaro Giménez',
#   'Centre-Forward',
#   31,
#   'Jun 30, 2023',
#   1100000.0,
#   'Cádiz CF')]

# %%
cur.execute("""
SELECT * FROM Query_Results;
""").fetchall()
# Out:
# [('Athletic Bilbao', 'Defenders', 65890000.0),
#  ('Athletic Bilbao', 'Forwards', 80850000.0),
#  ('Athletic Bilbao', 'Goalkeepers', 33000000.0),
#  ('Athletic Bilbao', 'Midfielders', 80850000.0),
#  ('Atlético de Madrid', 'Defenders', 168300000.0),
#  ('Atlético de Madrid', 'Forwards', 264000000.0),
#  ('Atlético de Madrid', 'Goalkeepers', 47850000.0),
#  ('Atlético de Madrid', 'Midfielders', 192500000.0),
#  ('CA Osasuna', 'Defenders', 46750000.0),
#  ('CA Osasuna', 'Forwards', 49500000.0),
#  ('CA Osasuna', 'Goalkeepers', 12210000.0),
#  ('CA Osasuna', 'Midfielders', 27940000.0),
#  ('Celta de Vigo', 'Defenders', 44000000.0),
#  ('Celta de Vigo', 'Forwards', 37950000.0),
#  ('Celta de Vigo', 'Goalkeepers', 5720000.0),
#  ('Celta de Vigo', 'Midfielders', 53900000.0),
#  ('Cádiz CF', 'Defenders', 21340000.0),
#  ('Cádiz CF', 'Forwards', 23100000.0),
#  ('Cádiz CF', 'Goalkeepers', 7480000.0),
#  ('Cádiz CF', 'Midfielders', 19580000.0),
#  ('Elche CF', 'Defenders', 21230000.0),
#  ('Elche CF', 'Forwards', 38500000.0),
#  ('Elche CF', 'Goalkeepers', 4180000.0),
#  ('Elche CF', 'Midfielders', 15510000.0),
#  ('FC Barcelona', 'Defenders', 254100000.0),
#  ('FC Barcelona', 'Forwards', 297000000.0),
#  ('FC Barcelona', 'Goalkeepers', 39270000.0),
#  ('FC Barcelona', 'Midfielders', 304700000.0),
#  ('Getafe CF', 'Defenders', 44880000.0),
#  ('Getafe CF', 'Forwards', 55000000.0),
#  ('Getafe CF', 'Goalkeepers', 9900000.0),
#  ('Getafe CF', 'Midfielders', 48950000.0),
#  ('Girona FC', 'Defenders', 32230000.0),
#  ('Girona FC', 'Forwards', 27280000.0),
#  ('Girona FC', 'Goalkeepers', 2860000.0),
#  ('Girona FC', 'Midfielders', 38390000.0),
#  ('RCD Espanyol Barcelona', 'Defenders', 25630000.0),
#  ('RCD Espanyol Barcelona', 'Forwards', 34650000.0),
#  ('RCD Espanyol Barcelona', 'Goalkeepers', 10340000.0),
#  ('RCD Espanyol Barcelona', 'Midfielders', 30800000.0),
#  ('RCD Mallorca', 'Defenders', 20680000.0),
#  ('RCD Mallorca', 'Forwards', 23870000.0),
#  ('RCD Mallorca', 'Goalkeepers', 12430000.0),
#  ('RCD Mallorca', 'Midfielders', 21780000.0),
#  ('Rayo Vallecano', 'Defenders', 23320000.0),
#  ('Rayo Vallecano', 'Forwards', 36300000.0),
#  ('Rayo Vallecano', 'Goalkeepers', 5610000.0),
#  ('Rayo Vallecano', 'Midfielders', 25520000.0),
#  ('Real Betis Balompié', 'Defenders', 69300000.0),
#  ('Real Betis Balompié', 'Forwards', 70950000.0),
#  ('Real Betis Balompié', 'Goalkeepers', 19800000.0),
#  ('Real Betis Balompié', 'Midfielders', 125950000.0),
#  ('Real Madrid', 'Defenders', 256300000.0),
#  ('Real Madrid', 'Forwards', 311300000.0),
#  ('Real Madrid', 'Goalkeepers', 68750000.0),
#  ('Real Madrid', 'Midfielders', 284900000.0),
#  ('Real Sociedad', 'Defenders', 100650000.0),
#  ('Real Sociedad', 'Forwards', 145750000.0),
#  ('Real Sociedad', 'Goalkeepers', 24530000.0),
#  ('Real Sociedad', 'Midfielders', 137500000.0),
#  ('Real Valladolid CF', 'Defenders', 17545000.0),
#  ('Real Valladolid CF', 'Forwards', 33000000.0),
#  ('Real Valladolid CF', 'Goalkeepers', 5170000.0),
#  ('Real Valladolid CF', 'Midfielders', 15950000.0),
#  ('Sevilla FC', 'Defenders', 94600000.0),
#  ('Sevilla FC', 'Forwards', 123200000.0),
#  ('Sevilla FC', 'Goalkeepers', 25300000.0),
#  ('Sevilla FC', 'Midfielders', 61050000.0),
#  ('UD Almería', 'Defenders', 33660000.0),
#  ('UD Almería', 'Forwards', 36520000.0),
#  ('UD Almería', 'Goalkeepers', 4620000.0),
#  ('UD Almería', 'Midfielders', 20900000.0),
#  ('Valencia CF', 'Defenders', 83050000.0),
#  ('Valencia CF', 'Forwards', 57200000.0),
#  ('Valencia CF', 'Goalkeepers', 24970000.0),
#  ('Valencia CF', 'Midfielders', 95700000.0),
#  ('Villarreal CF', 'Defenders', 134750000.0),
#  ('Villarreal CF', 'Forwards', 191400000.0),
#  ('Villarreal CF', 'Goalkeepers', 8470000.0),
#  ('Villarreal CF', 'Midfielders', 61600000.0)]

# %%
# closing connection
conn.close()
